# %% [markdown]
# # Assignment 2 - Henry Woodyard
#
# In the following two sections, I import necessary libraries and create useful functions. Please run these before proceeding to Question 1.

# %%
from pyspark.sql import SparkSession
from functools import reduce
import string
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("Learning_Spark") \
    .getOrCreate()

sc = spark.sparkContext

# %%
def GetAttributeValue(line, attribute, punct = False, spaces = False, numbers = True, returnNA = True):
    """
    Given a line of text in xml format and the name of an attribute, 
    this returns the value associated with the attribute.
    
    Arguments:
    line:      Line of XML text
    attribute: Attribute from line of XML text. e.g., "DisplayName"
    punct:     If false, removes punctuation
    spaces:    If true, and if punct is false, replaces punctuation with ' ' rather than ''
    numbers:   If true, keep numbers. Otherwise remove them.
    returnNA:  If an attribute cannot be found and this is true, returns the string 'NA'. Otherwise
               returns 0.
    """
    
    valueloc = [0,0]
    
    attrloc = line.find(attribute)
    if attrloc < 0:
        if returnNA:
            return 'NA'
        return 0
    
    valueloc[0] = attrloc + len(attribute) + 1
    valueloc[1] = valueloc[0] + line[valueloc[0] + 1:].find('\"')
    
    value = line[(valueloc[0] + 1):(valueloc[1] + 1)]
    
    if not numbers:
        value = value.translate(str.maketrans('0123456789', ' '*10))
    
    if punct:
        return value.lower()
    
    if spaces:
        value_nopunc = value.translate(str.maketrans(string.punctuation, ' '*len(string.punctuation)))
        return value_nopunc.lower()
    
    value_nopunc = value.translate(str.maketrans('', '', string.punctuation))
    
    return value_nopunc.lower()



def IsFromGeorgia(location):
    """
    Takes a location string as input and returns a bool for whether or not the location refers to 
    the Georgia, USA. Returns false if one of the ten most populous cities in the country of Georgia
    are in the string.
    """
    
    
    location = ' ' + location + ' '
    
    included = ['georgia', 'ga', 'atlanta']
    excluded = ['tbilisi', 'kutaisi', 'batumi', 'rustavi', 'sukhumi', 'zugdidi',
                'gori', 'poti', 'tskhinvali', 'samtredia']
  

    foundIncluded = list(filter(lambda i: location.find(' ' + i + ' ') >= 0, included))
    foundExcluded = list(filter(lambda i: location.find(' ' + i + ' ') >= 0, excluded))
    
    includeBool = len(foundIncluded) > 0
    excludeBool = len(foundExcluded) > 0

    if includeBool and not excludeBool:
        return True
    

    
def GetYear(date):
    """
    Takes date string as input and returns year
    """
    
    try:
        return date[0:4]
    except:
        return 0
    
    
def removeXMLFormatting(text):
    """
    Takes text string as input and removes common XML formatting
    """
    
    removalStrings = ['&#xd;', '&#xD;', '&#xa;', '&#xA;', '%watermark;', '&quot;', '&gt;', '&amp;',
                      '&lt;br', '&lt;']
    
    cleanText = text
    for removal in removalStrings:
        cleanText = cleanText.replace(removal, '')

    return cleanText

# %% [markdown]
# # Question 1
#
# Question Text: "From the Users.xml file, find all users which are from Georgia and output to screen their DisplayName only."

# %%
# Load user data
userdata = sc.textFile("Users.xml")

# Filter using the IsFromGeorgia classification function
georgiaUsers = userdata.filter(lambda line: IsFromGeorgia(GetAttributeValue(line, 'Location')))

# Print the names of users from the state of Georgia
for line in georgiaUsers.map(lambda line: GetAttributeValue(line, 'DisplayName', punct=True)).collect():
    print(line)
# Out:
# tony boyles
# pkerl
# nick larsen
# gfritz
# aleksandr blekh
# michael
# ayush
# azoorob
# ontek
# aravind r. yarram
# ilya
# vkb
# daisuke aramaki
# alexander stocko
# tempusfugit
# henry crutcher
# goddard
# matt simpson
# peter woolfitt
# matt biskup
# jason w
# peter mourfield
# magsol
# bob baxley
# badjr
# mplunney
# yc hu
# ryan
# patrick gerbes
# ilya lapitan
# dan anton
# pradyumnad
# dato janez
# psidom
# teresa madsen
# neuromeda
# brandon
# jpm
# mr. rooter of savannah
# mr. rooter of southeast ga
# khiem ha
# jenna kwon
# ahmet cecen
# jeff
# guy gordon
# c3theo
# niru dyogi
# vinitha palani
# mac18
# andrew
# aditya gogoi
# gh4x
# turtlemonvh
# lewis rodgers
# tarun luthra
# jesse scherer
# devendra lattu
# cosmosa
# todd dawson
# ironv
# mboolean
# jimd
# melinda weathers
# n.c.w.
# david f
# psinf
# chirag
# sandeep gunda
# hellofanengineer
# pavel komarov
# will gao
# oriol mirosa
# andrew king
# david
# rajb245
# sealander
# afshin
# ashish powani
# boris n.
# atul kaushik
# harnoor singh
# vincent
# tiago cogumbreiro
# cbarrick
# len greski
# red_eight
# pebkac
# christoph
# bryce
# david hofmann
# nburn42
# donlan
# nick m
# kiran
# barclayk
# zer0k
# dportman
# shishir suman
# scott
# jessicarabi
# baxter
# rama ananda
# dr. strange
# shahan m
# wgreenihrcorp
# zongyan
# alexandre
# rams
# john barbour
# the_flin
# daulpavid
# amandeep jiddewar
# erica rosa
# user1410665
# empoleon
# willie-g
# deepak shenoy
# ragnar lothbrok
# deontaé le pew
# doctorambient
# vidya
# vatsal srivastava
# dean webb
# tae-sung shin
# sam washburn
# loisaida sam sandberg
# wayne green
# gnorman
# clark lin
# floydian
# meng zhao
# manikanta reddy d
# devarsh raghnathbhai patel
# myron slaw
# rmooney
# mike_stevs
# gary lai
# ajroot
# daniel
# phos
# lance ruo zhang
# spencer-price
# stephen ewing
# alerera
# addi wei
# alex v
# rob
# rajan
# ram
# jgaboardi
# max boonbandansook
# zachdj
# david zhou
# ps0604
# treysp
# eduardo trunci
# squ1rr3lz
# tiji mathew
# user3776637

# %% [markdown]
# # Question 2
#
# Question Text: "Using the Users.xml file, provide the count for all users which joined (CreationDate) in 2017. Output this to the screen."

# %%
# Filters the RDD to only elements with CreationDates of 2017
madeIn2017 = userdata.filter(lambda line: GetYear(GetAttributeValue(line, 'CreationDate', punct = True)) == '2017')

# Gets the names of the users in the filtered RDD
users2017 = madeIn2017.map(lambda line: GetAttributeValue(line, 'DisplayName', punct = True))

print("A total of", users2017.count(), "users joined in 2017.")
# Out:
# A total of 14239 users joined in 2017.

# %% [markdown]
# # Question 3
#
# Question Text: "Using the PostHistory file, count the number of Posts that feature the words 'Spark' and 'Scala'. Output this to the screen. (20 points)"

# %%
# Import post history
posts = sc.textFile("PostHistory.xml")

# Remove common XML formatting from text. This helps identification of words.
posts = posts.map(lambda line: removeXMLFormatting(line))

# Require posts to have the words spark and scala
sparkScalaMentioned_NoSpace = posts.filter(lambda line: GetAttributeValue(line, 'Text').find('spark') > 0 
                                                and GetAttributeValue(line, 'Text').find('scala') > 0)

# Require posts to have the words spark or scala
sparkScalaMentioned_Space = posts.filter(lambda line: GetAttributeValue(line, 'Text').find(' spark ') > 0 
                                                and GetAttributeValue(line, 'Text').find(' scala ') > 0)

print("In both of the following methods, I do not subset by PostHistoryTypeId. This means that this methods \
searches over all elements in the PostHistory file, including titles, tags, etc.\n")

print("A total of", sparkScalaMentioned_Space.count(), "posts were found including the words 'spark' and 'scala' using a method \
requiring that the words be surrounded by spaces.\n")

print("A total of", sparkScalaMentioned_NoSpace.count(), "posts were found including the words 'spark' and 'scala' using a method \
that does not require that the words be surrounded by spaces. this could lead to words like \
'sparkling' and 'scalable' being counted, and is probably inflated.")
# Out:
# In both of the following methods, I do not subset by PostHistoryTypeId. This means that this methods searches over all elements in the PostHistory file, including titles, tags, etc.
#
# A total of 72 posts were found including the words 'spark' and 'scala' using a method requiring that the words be surrounded by spaces.
#
# A total of 202 posts were found including the words 'spark' and 'scala' using a method that does not require that the words be surrounded by spaces. this could lead to words like 'sparkling' and 'scalable' being counted, and is probably inflated.

# %% [markdown]
# # Question 4
#
# Question Text: "Using the PostHistory file, provide a total count of the words used by each distinct user. In other words, count all words in all posts for each user and display this to screen. You can only identify users by the UserID (30 points). You get 15 bonus points if you get the actual DisplayName of the user"

# %%
# Get only UserId and text. Don't filter by any type of PostHistoryTypeId.
userPosts = posts.map(lambda line: (GetAttributeValue(line, 'UserId', punct=True), 
                                    GetAttributeValue(line, 'Text', spaces=True, numbers=False)))

# Split the text for each user into a list of words.
userWords = userPosts.map(lambda pair: (pair[0], list(pair[1].split(" "))))

# Count the length of the list of words for each user.
counts = userWords.map(lambda pair: (pair[0], len(pair[1])))

# Because each user has multiple entries, reduce by key.
summedCounts = counts.reduceByKey(lambda x, y: x + y)

# Merge the DisplayNames from the user data file with the UserIds.
linkedNames = userdata.map(lambda line: (GetAttributeValue(line, 'Id', punct=True), 
                                         GetAttributeValue(line, 'DisplayName', punct=True)))
mergedNames = summedCounts.leftOuterJoin(linkedNames)

print("Displaying the number of words used by user for", mergedNames.count(), "users.")
print("(UserId, (Number of words, DisplayName))")

for line in mergedNames.collect():
    print(line)
# Out:
# Displaying the number of words used by user for 14103 users.
# (UserId, (Number of words, DisplayName))
# ('118', (1002, 'konstantin v. salikhov'))
# ('132', (1140, 'dvk'))
# ('199', (377, 'filipe ferminiano'))
# ('454', (1548, 'tomaskazemekas'))
# ('655', (81, 'will cairns'))
# ('471', (23984, 'spacedman'))
# ('913', (210, 'chrshmmmr'))
# ('960', (212, 'abdelmawla'))
# ('984', (4609, 'debasis'))
# ('1015', (392, 'divya'))
# ('819', (4481, 'charlie greenbacker'))
# ('1057', (432, 'mlespiau'))
# ('728', (399, 'jack twain'))
# ('924', (51554, 'anony-mousse'))
# ('1220', (115, 'islam el hosary'))
# ('1235', (1714, 'user3782364'))
# ('1271', (146, 'maxim fridental'))
# ('127', (240, 'rhand'))
# ('870', (546, 'arundhaj'))
# ('1386', (574, 'alext'))
# ('2583', (54, 'stenemo'))
# ('2648', (155, 'royalstream'))
# ('2798', (81, 'gleissongraca'))
# ('776', (354, '0111001101110000'))
# ('2883', (861, 'brycemcd'))
# ('2972', (202, 'mynameisjeff'))
# ('2997', (513, 'jessica mick'))
# ('3058', (91, 'seraphina'))
# ('3097', (61, 'user3097'))
# ('3259', (39, 'harjeet kumar'))
# ('3433', (183, 'innovismail'))
# ('3504', (10504, 'david fort myers'))
# ('3506', (268, 'rbk'))
# ('713', (89, 'smrati katiyar'))
# ('4679', (531, 'prudenko'))
# ('4736', (189, 'john'))
# ('4824', (235, 'denton101'))
# ('4999', (254, 'dan ahlquist'))
# ('5023', (169, 'k6adams'))
# ('5113', (715, 'hobbes'))
# ('5220', (146, 'bas'))
# ('5224', (2051, 'marcin kosiński'))
# ('5356', (670, 'rbaleksandar'))
# ('2742', (298, 'xtian'))
# ('6523', (1159, 'sagar patel'))
# ('6536', (36, 'zen'))
# ('6660', (62, 'cakesofwrath'))
# ('686', (94, 'jeremy salfen'))
# ('8030', (830, 'philip pearl'))
# ('8085', (1159, 'dvdnglnd'))
# ('8088', (1142, 'user17241'))
# ('3588', (94, 'harrison brock'))
# ('1376', (200, 'rainfield'))
# ('8462', (2058, 'victor'))
# ('8597', (312, 'konstantin'))
# ('8751', (165, 'servais daligou'))
# ('9097', (85, 'user1830108'))
# ('9219', (216, 'alexander'))
# ('9070', (2240, 'dan'))
# ('9390', (1319, 'student'))
# ('9369', (124, 'tmangin'))
# ('9472', (730, 'chappers'))
# ('9575', (203, 'giorgio spedicato'))
# ('9618', (595, 'demetri pananos'))
# ('10171', (924, 'blue-dino'))
# ('9838', (410, 'david'))
# ('8895', (90, 'bbs'))
# ('9946', (674, 'kalel'))
# ('1133', (1106, 'ricky'))
# ('9943', (1938, 'azrael'))
# ('10141', (158, 'monty'))
# ('10225', (116, 'digital dude'))
# ('10335', (97, 'uygar yologlu'))
# ('10429', (252, 'datadude'))
# ('10479', (543, 'vinay joshi'))
# ('10584', (1164, 'fakebrain'))
# ('947', (3908, 'david'))
# ('10253', (1105, 'enrique pérez herrero'))
# ('10751', (395, 'oopcode'))
# ('10811', (103, 'la_'))
# ('10836', (96, 'segmented'))
# ('10891', (76, 'rjz satvara'))
# ('9061', (281, 'nitin srivastava'))
# ('10949', (181, 'elliott rogasik'))
# ('10983', (1334, 'psql'))
# ('11063', (305, 'srinishine'))
# ('1324', (122, 'breezeintopl'))
# ('12172', (1249, 'michael'))
# ('12197', (91, 'jeremy needle'))
# ('12316', (38, 'jason.p.pickering'))
# ('12487', (212, 'dave'))
# ('12575', (2759, 'derek janni'))
# ('11136', (632, 'nbartley'))
# ('12527', (16054, 'laurent duval'))
# ('12770', (945, '0__'))
# ('12777', (226, 'dbliss'))
# ('12807', (35, 'albertod'))
# ('9025', (256, 'user2757902'))
# ('12996', (72, 'sredny m casanova'))
# ('13106', (321, 'doug fir'))
# ('13175', (175, 'daniel'))
# ('13274', (247, 'user239438'))
# ('13341', (167, 'brennon bortz'))
# ('13457', (768, 'anuj gupta'))
# ('13498', (299, 'michael green'))
# ('13516', (84, 'alfagera'))
# ('13521', (905, 'chr0x'))
# ('13529', (183, 'user2726995'))
# ('13606', (164, 'muhammet ali asan'))
# ('13686', (5792, 'wabbit'))
# ('12521', (156, 'brendan'))
# ('13943', (103, 'asymtrick'))
# ('14031', (1486, 'hobs'))
# ('14154', (289, 'okebz'))
# ('14294', (185, 'vaibhav srivastava'))
# ('14556', (306, 'jonepatr'))
# ('2981', (583, 'biswajit banerjee'))
# ('14749', (97, 'jesse'))
# ('14763', (287, 'sudeepgupta90'))
# ('14909', (5229, 'make42'))
# ('14895', (31, 'kilojoules'))
# ('15128', (176, 'ved'))
# ('14789', (850, 'shaleen jain'))
# ('15258', (72, 'ikuyasu'))
# ('15311', (106, 'crizly'))
# ('15373', (88, 'nolatar'))
# ('15398', (402, 'matt harvey'))
# ('15695', (1173, 'wassimply'))
# ('15784', (350, 'joec'))
# ('15786', (278, 'palla'))
# ('13688', (399, 'addictedtohaskell'))
# ('16197', (295, 'anindit karmakar'))
# ('16119', (85, 'виталий радченко'))
# ('848', (134, 'woodstock'))
# ('16511', (225, 'hans ziqiu li'))
# ('16680', (817, 'dennis golomazov'))
# ('16808', (506, 'hakunin'))
# ('9565', (939, 'max candocia'))
# ('17055', (49, 'ds_user'))
# ('17045', (635, 'hooge'))
# ('17246', (689, 'profmeowsworth'))
# ('16774', (134, 'user106751'))
# ('17415', (161, 'aviel fedida'))
# ('17446', (285, 'mandar chandorkar'))
# ('17469', (129, 'hans periag'))
# ('17503', (374, 'austin'))
# ('10301', (101, '404pio'))
# ('17596', (922, 'john newman'))
# ('17712', (217, 'jean carré'))
# ('17806', (4890, 'armatita'))
# ('17828', (178, 'd-nice'))
# ('17908', (228, 'changwang zhang'))
# ('17939', (48, 'user3435407'))
# ('18012', (554, 'chinmay kanchi'))
# ('16001', (417, 'rabbit'))
# ('17484', (4482, 'hipoglucido'))
# ('18200', (265, '26lane'))
# ('18271', (304, 'dider'))
# ('18354', (4335, 'fagui curtain'))
# ('18364', (971, 'wythagoras'))
# ('18538', (113, 'yuqing'))
# ('18609', (282, 'lior'))
# ('18703', (4302, 'upper_case'))
# ('18934', (38, 'chinmay joshi'))
# ('18951', (948, 'user24984'))
# ('14826', (30, 'alex'))
# ('19258', (51, 'dariush'))
# ('19265', (280, 'dan piponi'))
# ('18510', (511, 'cabana'))
# ('20338', (337, 'silentmiles'))
# ('20445', (129, 'thegreenpizza'))
# ('20448', (560, 'alexei martianov'))
# ('20477', (132, 'lobna alnabbash'))
# ('20509', (1506, 'lukas k.'))
# ('20517', (1465, 'rahul sharma'))
# ('12285', (68, 'trần đức nhuận'))
# ('20571', (769, 'bleedobsidian'))
# ('12345', (8099, 'arkan'))
# ('20635', (477, 'armon safai'))
# ('18039', (178, 'rex remus'))
# ('8664', (405, 'ayhan'))
# ('17635', (114, 'jack'))
# ('20766', (3511, 'nikhil verma'))
# ('18544', (4091, 'sqlserversteve'))
# ('16213', (748, 'aventurin'))
# ('20873', (43, 'jame_smith'))
# ('21079', (359, 'andy w'))
# ('21234', (49, 'ytk'))
# ('21281', (533, 'juha'))
# ('21291', (1021, 'winterflags'))
# ('21381', (89, 'amir ladhar'))
# ('10423', (295, 'niranjan mudhiraj'))
# ('21608', (9911, 'himanshu rai'))
# ('21638', (344, 'user1813867'))
# ('14955', (168, 'gabrer'))
# ('21713', (72, 'pati'))
# ('23182', (47, 'technicaltim'))
# ('21182', (176, 'seth'))
# ('23278', (196, 'chen kinnrot'))
# ('18022', (322, 'eli-k'))
# ('23416', (3507, 'patapouf_ai'))
# ('23452', (974, 'rachel'))
# ('23469', (148, 'tak'))
# ('23495', (928, 'carlo mazzaferro'))
# ('23571', (51, 'heybati'))
# ('23818', (213, 'simon'))
# ('21719', (301, 'nbwl'))
# ('23921', (57, 'pythonguy'))
# ('23971', (180, 'socialmatrix'))
# ('12972', (104, 'joc'))
# ('24019', (73, 'user28724'))
# ('24024', (202, '3x89g2'))
# ('24235', (329, 'aditya kumar gupta'))
# ('20723', (1128, 'gregorymatchado'))
# ('24412', (862, 'reii nakano'))
# ('24682', (349, 'kyriakos'))
# ('4784', (96, 'angleto'))
# ('24980', (844, 'burakumin'))
# ('25188', (4983, 'j.down'))
# ('25238', (340, 'carlos dutra'))
# ('25301', (30, 'vishalvikram'))
# ('25309', (81, 'vivek srinivasan'))
# ('25353', (827, 'sagar b hathwar'))
# ('23238', (244, 'oscar'))
# ('16688', (88, 'abbypaden'))
# ('23983', (390, 'jason feng'))
# ('25881', (237, 'anuj'))
# ('25923', (67, 'arvind gurjar'))
# ('25934', (167, 'thomas pinetz'))
# ('25936', (88, 'jérémy pouyet'))
# ('25976', (77, 'jayaprakash sundararaj'))
# ('25983', (1097, 'user2835098'))
# ('26019', (65662, 'ebrahimi'))
# ('10992', (317, 'sanjeev'))
# ('26341', (113, 'anonymous'))
# ('26470', (203, 'cheshire'))
# ('26474', (299, 'john kenis'))
# ('26519', (701, 'molig'))
# ('26643', (2023, 'torben.'))
# ('26791', (418, 'fanfabbb'))
# ('26828', (196, 'benjamin.t'))
# ('24245', (281, 'user3824382'))
# ('26902', (568, 'david b'))
# ('26907', (328, 'david groppe'))
# ('26956', (266, 'chia wj'))
# ('26976', (323, 'ashish kulkarni'))
# ('26413', (2467, 'michail michailidis'))
# ('27202', (225, 'l..'))
# ('27566', (1473, 'mtariq'))
# ('27613', (172, 'rishabh gupta'))
# ('2975', (1209, 'deong'))
# ('27645', (430, 'anat'))
# ('27668', (167, 'noah chalifour'))
# ('27682', (97, '铭声孙'))
# ('27702', (529, 'nat'))
# ('27902', (122, 'wwjdm'))
# ('27872', (923, 'saurabh verma'))
# ('27935', (366, 'kuen'))
# ('27984', (174, 'yossico'))
# ('28152', (82, 'john albano'))
# ('27683', (702, 'agwah'))
# ('28209', (889, 'agentlerose'))
# ('28367', (1501, 'user34018'))
# ('28611', (6506, 's.n.'))
# ('27928', (4, 'aberger'))
# ('17727', (124, 'zebra propulsion lab'))
# ('28986', (109, 'gal isra'))
# ('3299', (513, 'snshines'))
# ('28809', (265, 'jan wrona'))
# ('29083', (4562, 'adam sypniewski'))
# ('29256', (120, 'david'))
# ('29128', (143, 'subin sahayam'))
# ('29408', (99, 'damian anslik'))
# ('29190', (124, 'sylvain m'))
# ('29498', (1136, 'paul jurczak'))
# ('29512', (137, 'sugarcube corner'))
# ('29556', (299, 'paco barter'))
# ('8262', (20, 'zbinsd'))
# ('29000', (1522, 'tafteh'))
# ('29685', (151, 'lewis rodgers'))
# ('29732', (196, 'paolo vigori'))
# ('29744', (186, 'nhat nguyen'))
# ('29008', (1039, 'vdvaxel'))
# ('29806', (583, 'basse'))
# ('29952', (112, 'tromesh'))
# ('29987', (84, 'python novice'))
# ('29999', (142, 'john'))
# ('30035', (90, 'user30035'))
# ('30036', (1855, 'alex firsov'))
# ('30006', (4963, 'manik'))
# ('30039', (35, 'futuregeek'))
# ('30043', (1351, 'alireza'))
# ('30210', (2221, 'kaare'))
# ('30781', (74, 'vineet kothari'))
# ('30859', (191, 'sokokaleb'))
# ('30928', (3170, 'thomas w'))
# ('31038', (4591, 'hilad'))
# ('31069', (275, 'domino7'))
# ('31089', (42, 'karthik sekaran'))
# ('31088', (235, 'sebastian rosloniec'))
# ('31102', (49, 'sac7e'))
# ('31110', (196, 'laughingman'))
# ('30507', (4294, 'ran8'))
# ('31364', (233, 'vikotse'))
# ('31391', (97, 'husam'))
# ('31513', (36142, 'vividd'))
# ('31475', (46, 'noodle'))
# ('31627', (317, 'vitaly portnoy'))
# ('30675', (109, 'kadeg'))
# ('31988', (194, 'user31988'))
# ('31781', (607, 'jeffery_the_wind'))
# ('32012', (132, 'martin krämer'))
# ('32095', (193, 'sayan'))
# ('30898', (291, 'john'))
# ('32373', (118, 'namra saheba'))
# ('30959', (811, 'thegoat'))
# ('32806', (155, 'tanmay deshpande'))
# ('33194', (1080, 'xiaohan2012'))
# ('33245', (1632, 'keramat'))
# ('33453', (1045, 'severine'))
# ('33509', (251, 'samyak jain'))
# ('33515', (169, 'motiur'))
# ('33530', (1430, 's4nd33p'))
# ('16212', (852, 'sheridan grant'))
# ('33604', (152, 'jenny faig'))
# ('33609', (276, 'janm'))
# ('33642', (215, 'user2950747'))
# ('33677', (578, 'diogenesthedog'))
# ('32763', (41, 'brandon'))
# ('33831', (177, 'cartman'))
# ('33941', (1503, 'marcus '))
# ('33926', (122, 'sanket kedia'))
# ('31093', (197, 'patrick zawadzki'))
# ('34092', (2318, 'ofer sadan'))
# ('34213', (466, 'ji weizhen'))
# ('34310', (117, 'z80crew'))
# ('35405', (164, 'md612'))
# ('35512', (256, 'royalswish'))
# ('35650', (2700, 'w.p. mcneill'))
# ('35679', (5717, 'christos karatsalos'))
# ('35764', (409, 'dumkar'))
# ('35795', (1679, 'rainbow unicorn'))
# ('35829', (111, 'allyl isocyanate'))
# ('36935', (3613, 'aweeeezy'))
# ('37149', (186, 'skylar'))
# ('37196', (425, 'leo c'))
# ('26239', (186, 'hellogoodbye'))
# ('37225', (226, 'lucasramos'))
# ('37298', (712, 'i.k.'))
# ('37345', (2134, 'jd1338'))
# ('37397', (601, 'joby'))
# ('37664', (298, 'steven chen'))
# ('37804', (197, 'dgib'))
# ('17810', (225, 'emin alasgarov'))
# ('38086', (682, 'mathreadler'))
# ('38385', (130, 'iman'))
# ('38395', (1307, 'smith volka'))
# ('38419', (547, 'yangguang'))
# ('37217', (361, 'arqam'))
# ('30641', (95, 'deepak m'))
# ('38790', (516, 'dpk'))
# ('31776', (251, 'physincubus'))
# ('33134', (862, 'cyan cevi'))
# ('38818', (200, 'prashant'))
# ('37924', (359, 'chrisckwong821'))
# ('39052', (691, 'leonard strnad'))
# ('39158', (137, 'mzavaletavargas'))
# ('38917', (1007, 'aalberti333'))
# ('39234', (2426, 'tomar__'))
# ('38894', (1, 'farewell stack exchange'))
# ('26173', (266, 'climbsrocks'))
# ('39437', (508, 'markus777'))
# ('39613', (316, 'o.s'))
# ('38054', (1872, 'peter'))
# ('39663', (50, 'dirk nachbar'))
# ('39653', (33, 'klodd'))
# ('8875', (70, 'rob'))
# ('39223', (3203, 'ray tayek'))
# ('39965', (276, 'animesh'))
# ('40020', (83, 'amit srivastava'))
# ('39764', (188, 'tildekara'))
# ('40255', (171, 'steves'))
# ('40378', (207, 'aghd'))
# ('40400', (755, "fritz o'connor"))
# ('40480', (88, 'michalina'))
# ('40540', (970, 'math j'))
# ('40545', (290, 'pvp'))
# ('40564', (1878, 'ary'))
# ('30000', (199, 'bharadwaj aldur'))
# ('26493', (247, 'kosmos'))
# ('41051', (182, 'james d'))
# ('29781', (12940, 'aivanov'))
# ('31464', (348, 'mojtaba komeili'))
# ('27944', (220, 'hpwsue'))
# ('41312', (1244, 'suresh kasipandy'))
# ('41446', (46, 'herdiansc'))
# ('41535', (293, 'alexander okunev'))
# ('41454', (184, 'b k'))
# ('41612', (436, 'katherine'))
# ('41073', (663, 'jaggi'))
# ('41854', (340, 'hunter mcgushion'))
# ('41886', (9181, 'tom'))
# ('41888', (1402, 'tanguy'))
# ('41948', (255, 'aladagemre'))
# ('41968', (1232, 'meiiso'))
# ('41990', (253, 'daniel'))
# ('42225', (143, 'vuduc'))
# ('6656', (55, 'habedi'))
# ('42419', (205, 'hellboy'))
# ('42457', (293, 'user4155621'))
# ('40815', (4002, 'anupam bisht '))
# ('31819', (744, 'neves'))
# ('42622', (1475, 'jurgy'))
# ('40265', (221, 't.poe'))
# ('42694', (100, 'user3483880'))
# ('42985', (56, 'chase kregor'))
# ('14929', (99, 'ashrithgande'))
# ('43159', (338, 'pedrogfp'))
# ('43476', (824, 'russell butler'))
# ('43488', (33, 'thomas f'))
# ('43495', (50, 'mark yang'))
# ('43491', (662, 'abdullahi mohammad'))
# ('43594', (25, 'double-d'))
# ('43608', (1174, 'stijn'))
# ('43635', (916, 'pinenuts0'))
# ('43649', (175, 'robinl'))
# ('23482', (149, 'ulderique demoitre'))
# ('43848', (60, 'l.zhang'))
# ('43921', (1718, 'rkz'))
# ('43256', (472, 'len greski'))
# ('40102', (1166, 'shiva manhar'))
# ('26784', (71, 'mani'))
# ('44143', (203, 'elvisalive'))
# ('44169', (157, 'blabla'))
# ('44488', (194, 'clement attlee'))
# ('44712', (99, 'jon austin'))
# ('44725', (134, 'learnningprogramming'))
# ('44726', (10640, 'a s'))
# ('44838', (28, 'user2969932'))
# ('44991', (252, 'rafty'))
# ('45181', (238, 'maxwell omdal'))
# ('45183', (448, 'articuno'))
# ('43048', (830, 'matthew ciaramitaro'))
# ('45371', (282, 'kaulmonish'))
# ('45448', (63, 'gregory boyle'))
# ('45485', (317, 'sunsets'))
# ('44714', (388, 'yuki.u'))
# ('45898', (866, 'user121'))
# ('45957', (98, 'raton roguille'))
# ('15902', (4143, 'the6thsense'))
# ('46068', (75, 'malay hazarika'))
# ('46104', (2599, 'mateusz bielecki'))
# ('45224', (1510, 'nikhil wagh'))
# ('25635', (74, 'jeremiah'))
# ('46279', (105, 'daleadil'))
# ('46288', (1307, 'glorfendal'))
# ('46371', (750, 'ajinkya'))
# ('46375', (2074, 'qwerto'))
# ('46488', (937, 'paul'))
# ('46293', (696, 'gurvinder372'))
# ('38271', (1334, 'jshep'))
# ('46595', (2866, 'user8919'))
# ('16879', (208, 'udaykumarverma'))
# ('46618', (44, 'iam riz'))
# ('9910', (433, 'deanla'))
# ('46785', (521, 'grozail'))
# ('38672', (307, 'xyand'))
# ('46869', (154, 'quan duong'))
# ('46886', (1291, 'jchaykow'))
# ('46893', (66, 'pooja'))
# ('47022', (1350, 'cathyqian'))
# ('45764', (2030, 'sato'))
# ('47233', (371, 'adnan saood'))
# ('47250', (139, 'mitch'))
# ('2584', (45, 'andrew brēza'))
# ('47411', (233, 'joseph yourine'))
# ('47600', (752, 'sspp'))
# ('47698', (197, 'harini vaidyanath'))
# ('47724', (991, 'gokul nc'))
# ('47728', (204, 'saumya sambit acharya'))
# ('47785', (156, 'jacob martin'))
# ('48992', (100, 'santosh gupta'))
# ('46242', (151, 'jogging song'))
# ('49119', (2100, 'junjiechen'))
# ('49154', (240, 'youngam'))
# ('49377', (146, 'primusa'))
# ('47750', (257, 'mahdi shahbaba'))
# ('49577', (747, 'cjc'))
# ('49617', (241, 'itaysason'))
# ('46454', (231, 'tingting'))
# ('49852', (1069, 'sr_ml'))
# ('49925', (440, 'adam erickson'))
# ('49952', (188, 'tarun kumar'))
# ('49980', (174, 'taiidan'))
# ('50007', (745, 'serciosoydanov'))
# ('50025', (689, 'ollie'))
# ('50155', (167, 'dypbrg'))
# ('50154', (665, 'dato gogolashvili'))
# ('50235', (43, 'omair k'))
# ('50256', (336, 'amit khanna'))
# ('50471', (966, 'mbdev'))
# ('50494', (299, 'blagblug1987'))
# ('50515', (582, 'user9645302'))
# ('50528', (223, 'j_k_j'))
# ('50563', (49, 'ashish vankudre'))
# ('50603', (676, 'arush1836'))
# ('17000', (143, 'm. mashayekhi'))
# ('50623', (104, 'user3089520'))
# ('50768', (141, 'user2404894'))
# ('50925', (65, 'iamlemec'))
# ('50950', (207, 'guerlando ocs'))
# ('50991', (2212, 'prashant pandey'))
# ('51089', (496, 'franklin dong'))
# ('51139', (101, 'lenoir'))
# ('51129', (12432, 'n.it'))
# ('51153', (3045, 'bon ryu'))
# ('51411', (347, 'tryingtolearn'))
# ('51440', (58, 'naser piltan'))
# ('51453', (235, 'alex dometrius'))
# ('51601', (90, 'user8250319'))
# ('51685', (818, 'r.yan'))
# ('47257', (486, 'user1253952'))
# ('51808', (78, 'ryan l'))
# ('51870', (416, 'el tikki'))
# ('51988', (1101, 'statsanalyst'))
# ('52148', (80, 'mhmhsh'))
# ('6641', (65, 'eilia'))
# ('52371', (803, 'spurious'))
# ('34158', (106, 'dward4'))
# ('52538', (256, 'infojunkie'))
# ('52621', (285, 'legeniusii'))
# ('52653', (71, 'yassine'))
# ('52678', (2837, 'idriss'))
# ('52722', (284, 'user52722'))
# ('52793', (2464, 'sven laschinski'))
# ('37997', (652, 'shiny'))
# ('52929', (181, 'lord aj'))
# ('52713', (422, 'da-le'))
# ('53127', (187, 'piccolo'))
# ('53148', (264, 'vash'))
# ('53215', (132, 'mohammed obeidat'))
# ('52975', (502, 'moras'))
# ('26187', (576, 'lhk'))
# ('49017', (1091, 'lads'))
# ('53505', (274, 'isaac t'))
# ('53543', (1170, 'hcg'))
# ('53682', (32, 'user53682'))
# ('53758', (706, 'sharvari gc'))
# ('53789', (2397, 'yaskovdev'))
# ('53715', (200, 'ryszard cetnarski'))
# ('53804', (828, 'qa collective'))
# ('53799', (2803, 'user53799'))
# ('53747', (366, 'roding'))
# ('53946', (181, 'zaynab'))
# ('53971', (100, 'yashveer singh yadav'))
# ('54044', (722, 'bertrand'))
# ('53039', (974, 'h froedge'))
# ('54054', (32, 'user2502904'))
# ('54187', (937, 'rubio95r'))
# ('54270', (147, 'user54270'))
# ('53639', (357, 'nedzad g'))
# ('54426', (67, 'maufcost'))
# ('54534', (1422, 'ignacio alorre'))
# ('54575', (203, 'adhish thite'))
# ('54590', (39, 'hadij'))
# ('54600', (67, 'miquel artigues'))
# ('50123', (250, 'mohamed amine ouali'))
# ('54671', (192, 'jana dodson'))
# ('53322', (384, 'scott'))
# ('54364', (238, 'ali'))
# ('56342', (445, 'armen'))
# ('56412', (300, 'harigovind valsakumar'))
# ('53157', (521, 'anx199'))
# ('56895', (95, 'andre myers'))
# ('56928', (763, 'ariel goldstein'))
# ('56946', (114, 'myonaiz'))
# ('56906', (1238, 'luxspes'))
# ('57072', (197, 'cody maughan'))
# ('57108', (160, 'muhammad usman'))
# ('57141', (282, 'mrt'))
# ('54661', (503, 'mehran'))
# ('53337', (626, 'loco.loop'))
# ('57351', (67, 'user57351'))
# ('57353', (434, 'charlene'))
# ('57421', (121, 'sleeba paul'))
# ('57506', (149, 'bbodek'))
# ('57632', (726, 'seungjaeryanlee'))
# ('53937', (92, 'supamee'))
# ('57679', (426, 'xiphias'))
# ('57722', (158, 'aniruddh khera'))
# ('57623', (546, 'user57623'))
# ('57866', (134, 'madhurjya sharma'))
# ('57906', (260, 'm3h0w'))
# ('41631', (129, 'pankaj joshi'))
# ('57727', (689, 'srj577'))
# ('57382', (277, 'knrumsey'))
# ('58311', (208, 'harshil shah'))
# ('58433', (9430, 'user10296606'))
# ('58488', (7911, 'from keras import michael'))
# ('58628', (514, 'liyuan'))
# ('58660', (340, 'robinson crusoe'))
# ('58736', (1124, 'akash dubey'))
# ('58802', (299, 'user58802'))
# ('58827', (16, 'patel ashutosh'))
# ('58449', (2419, 'boris mulder'))
# ('59032', (375, 'sjoseph'))
# ('59078', (161, 'coding247'))
# ('59127', (1831, 'karthi1234'))
# ('59142', (322, 'jerome'))
# ('43326', (215, 'hatmatrix'))
# ('39709', (65, 'pavel k'))
# ('59035', (428, 'jair'))
# ('59385', (454, 'fred'))
# ('59467', (517, 'schaefferda'))
# ('56230', (429, 'akhil alexander'))
# ('6586', (306, 'adamc91'))
# ('59737', (696, 'beginner'))
# ('59854', (328, 'benj cabalona jr.'))
# ('59931', (345, 'pattpoo'))
# ('59954', (192, 'nikhil pandarge'))
# ('57925', (66, 'jorge herrera'))
# ('60053', (90, 'saswata biswas'))
# ('60136', (75, 'alwin aind'))
# ('60213', (120, 'prativa das'))
# ('38173', (312, 'md. rezwanul haque'))
# ('60325', (192, 'skary'))
# ('60332', (124, 'akhilesh sayana'))
# ('60392', (95, 'bluedogvip'))
# ('57918', (140, 'furqan hashim'))
# ('60542', (222, 'gistiv'))
# ('60503', (4712, 'romain reboulleau'))
# ('60612', (29, 'bharat teja'))
# ('60620', (221, 'rachit tayal'))
# ('60652', (77, 'mudit'))
# ('60753', (259, 'emilyfy'))
# ('50166', (92, 'franneck'))
# ('60851', (88, 'mangla'))
# ('61025', (51, 'user1947921'))
# ('61035', (208, 'tiberiu'))
# ('61071', (786, 'mano'))
# ('61210', (4667, 'shivam singh'))
# ('61233', (50, 'eamonn keogh'))
# ('61257', (69, 'will sabol'))
# ('61334', (276, 'pratik_katte'))
# ('53812', (9003, 'antonio jurić'))
# ('61580', (701, 'chris'))
# ('24847', (74, 'dozyaustin'))
# ('61706', (964, 'aristodog'))
# ('61681', (162, 'shroomy'))
# ('61787', (151, 'josh grossman'))
# ('39061', (16, 'fatma.s.gadelrab'))
# ('62083', (460, 'duncan milne'))
# ('62184', (385, 'isabelle guyon'))
# ('54151', (129, 'vince miller'))
# ('62381', (305, 'tajrian mollick'))
# ('62386', (5752, 'chris kehl'))
# ('62423', (1062, 'younus ali'))
# ('62436', (252, 'мајдејсаремех'))
# ('62479', (290, 'kasy chakra'))
# ('40735', (139, 'guille'))
# ('62596', (24, 'timcdlucas'))
# ('62625', (136, 'cemre'))
# ('62670', (120, 'son kun'))
# ('53453', (444, 'britodfbr'))
# ('62846', (8463, '不是phd的phd'))
# ('51603', (844, 'abdul rehman'))
# ('63129', (2559, 'jengmge'))
# ('62762', (402, 'belphegor'))
# ('63287', (67, 'francisco j. díez'))
# ('63388', (406, 'robin desbois'))
# ('63390', (533, 'reslan tinawi'))
# ('54953', (3543, 'dylan'))
# ('63471', (865, 'harry stuart'))
# ('63548', (445, 'deni avinash'))
# ('63561', (138, 'user2405694'))
# ('24858', (483, 'mindfreak'))
# ('50833', (26131, 'mark.f'))
# ('63701', (189, 'youngresearcher'))
# ('63712', (3174, 'sudeep banik'))
# ('63810', (331, 'rjzii'))
# ('64035', (2708, 'tamil selvan s'))
# ('6598', (861, 'anchika agarwal'))
# ('64127', (54, 'timo k.'))
# ('64247', (34, 'anup doddamane'))
# ('64315', (688, 'etienne ott'))
# ('64392', (41, 'chinmayg'))
# ('64425', (46, 'ibug'))
# ('64580', (536, 'hmircead'))
# ('64533', (847, 'lasul'))
# ('64659', (240, 'silentsudo'))
# ('64795', (667, 'i.d.m'))
# ('64961', (41, 'user'))
# ('65022', (16246, 'palisadoes'))
# ('65228', (3048, 'maksylon'))
# ('63649', (1117, 'marcelo'))
# ('65273', (144, 'arjun chandra'))
# ('65295', (204, 'user1964692'))
# ('65371', (333, 'osama anmar'))
# ('38330', (327, 'sam hammamy'))
# ('65521', (80, 'kunal'))
# ('65529', (54, 'sayeed'))
# ('65533', (70, 'crazymageqi'))
# ('65872', (213, 'jamie'))
# ('65965', (303, 'chris'))
# ('64304', (4433, 'neerajan saha'))
# ('66078', (49, 'jhdoe'))
# ('66127', (137, 'tiago albineli motta'))
# ('66137', (106, 'imen sui'))
# ('66138', (72, 'raneez ahmed'))
# ('66117', (16239, 'kikio'))
# ('66192', (1002, 'remus raphael'))
# ('56647', (94, 'rupesh prasad'))
# ('66372', (1058, 'shekhar tanwar'))
# ('66421', (345, 'mlanon'))
# ('66481', (194, 'pablo'))
# ('66552', (367, 'oscar martinez'))
# ('66565', (1941, 'user637140'))
# ('66639', (245, 'sam'))
# ('66656', (232, 'mbass'))
# ('66679', (62, 'qmars'))
# ('66737', (2005, 'dbm'))
# ('66985', (146, 'jonathan'))
# ('67008', (378, 'hamish mcbrearty'))
# ('66736', (626, 'antoine savine'))
# ('67069', (487, 'ayumu kasugano'))
# ('60818', (372, 'abhimanyu aryan'))
# ('67270', (361, 'aad2'))
# ('58418', (243, 'cody rutscher'))
# ('64115', (126, 'mohit saini'))
# ('67514', (877, 'karmapl'))
# ('67612', (125, 'zubikabubi'))
# ('67427', (160, 'alejandro celis'))
# ('67658', (224, 'finebalance'))
# ('67851', (31, 'anroop'))
# ('67909', (56, 'haggui ayoub'))
# ('52601', (257, 'moreno'))
# ('67968', (204, 'ricvo'))
# ('68023', (14420, 'shubham panchal'))
# ('67504', (356, 'david atlas'))
# ('67887', (252, 'nyos'))
# ('68174', (9473, 'needingmlhelp'))
# ('52212', (879, 'alec k'))
# ('68254', (92, 'shreyans'))
# ('68345', (270, 'rishab gupta'))
# ('68364', (150, 'cameraguy258'))
# ('49795', (638, 'bitswazsky'))
# ('68280', (103, 'sundara kesavan'))
# ('68386', (168, 'xyan'))
# ('68421', (2154, 'steven cunden'))
# ('68214', (103, 'zouhair elhadi'))
# ('68517', (163, 'amruth'))
# ('68549', (135, 'tmk'))
# ('68617', (525, 'timothy hedgeworth'))
# ('68727', (179, 'oliver searle-barnes'))
# ('68738', (251, 'sam whitlock'))
# ('68877', (149, 'user1439018'))
# ('68950', (614, 'genericname'))
# ('68963', (102, 'gurmeet singh'))
# ('68988', (66, 'epsilones'))
# ('68999', (405, 'gaurav dogra'))
# ('69023', (196, 'frankshore'))
# ('69044', (804, 'saketh ramchandani'))
# ('69073', (508, 'stanislav jirak'))
# ('69082', (192, 'agnius vasiliauskas'))
# ('69213', (542, 'jibril'))
# ('69249', (333, 'user69249'))
# ('69352', (279, 'mark presser'))
# ('69397', (374, 'jeb02'))
# ('51816', (80, 'reeves'))
# ('69408', (108, 'shenflow'))
# ('69212', (1038, 'izzo'))
# ('69452', (3942, 'user2816215'))
# ('69528', (946, 'it experts'))
# ('69621', (61, 'arshad_221b'))
# ('69746', (928, 'patrick balada'))
# ('42226', (1046, 'david guez'))
# ('69798', (45, 'guest'))
# ('69841', (99, 'stephen clark'))
# ('69851', (107, 'jwh2006'))
# ('70098', (503, 'komunistbakkal'))
# ('70325', (160, 'kalyan katikapalli'))
# ('47791', (1270, 'tom hale'))
# ('70435', (131, 'user70435'))
# ('70458', (904, 'xvlaze'))
# ('70555', (7007, 'user3613025'))
# ('70697', (193, 'andy'))
# ('70776', (173, 'jack farah'))
# ('70875', (126, 'oman'))
# ('70927', (762, 'which_command'))
# ('71047', (111, 'bien'))
# ('71105', (90, 'prabhakar267'))
# ('52841', (97, 'johannes klaus'))
# ('63257', (107, 'erick díaz'))
# ('7916', (739, 'davergp'))
# ('71198', (977, 'tobix10'))
# ('70887', (1332, 'ford1892'))
# ('66272', (172, 'adityagaydhani'))
# ('71541', (475, 'stefan'))
# ('71587', (5373, 'annonymous programmer'))
# ('71602', (1217, 'whocares'))
# ('71619', (91, 'lewis0112'))
# ('71633', (3226, 'pavlovscat'))
# ('71666', (778, 'rnne msly'))
# ('71684', (138, 'ralf köhler'))
# ('71689', (204, 'victor khodalov'))
# ('71759', (376, 'leo brueggeman'))
# ('18247', (1742, 'andrew maurer'))
# ('71861', (1913, 'disney82231'))
# ('71895', (259, 'user71895'))
# ('71964', (2717, 'aoj'))
# ('72008', (404, 'user6710'))
# ('72009', (178, 'morteza'))
# ('73298', (2298, 'josiah l.'))
# ('73364', (100, 'user3444337'))
# ('73410', (317, 'laryx decidua'))
# ('73405', (220, 'nachiketsd'))
# ('73473', (73, 'matlock779'))
# ('73491', (48, 'sam komo'))
# ('73567', (213, 'goking'))
# ('73586', (154, 'user220641'))
# ('73622', (553, 'amer farooq'))
# ('73512', (704, 'anjani'))
# ('71026', (694, 'kibassa j.'))
# ('73290', (129, 'yoyong'))
# ('73721', (405, 'bengya'))
# ('73726', (141, 'ann'))
# ('73832', (1496, 'junmouse'))
# ('73899', (95, 'anshul yadav'))
# ('73996', (316, 'hey0'))
# ('69498', (174, 'demarsylvain'))
# ('68137', (190, 'георги кременлиев'))
# ('73967', (756, 'polmonroig'))
# ('74018', (338, 'tim weah'))
# ('74047', (135, 'viacheslav varenia'))
# ('29875', (864, 'malintha'))
# ('74207', (2505, 'saksham'))
# ('47505', (299, 'manoj'))
# ('52128', (538, 'laura'))
# ('74348', (108, 'negar'))
# ('74369', (243, 'f_m'))
# ('74392', (334, 'michael de santa'))
# ('74441', (107, 'marton langa'))
# ('74477', (87, 'kck'))
# ('74506', (965, 'theta'))
# ('74540', (245, 'tadejk'))
# ('74574', (110, 'zachary'))
# ('74617', (1146, 'the_chicken_lord'))
# ('74640', (1296, 'datascienceaspirant'))
# ('73785', (461, 'snr'))
# ('74697', (408, 'nam'))
# ('74738', (231, 'solumnant'))
# ('74846', (1565, 'bakaburg'))
# ('74922', (238, 'praveenkumar'))
# ('62599', (59, 'matohak'))
# ('75044', (89, 'grkiran2011'))
# ('75055', (3896, 'yash jakhotiya'))
# ('75178', (951, 'alex winters'))
# ('75213', (205, 'rlucas'))
# ('75224', (149, 'maura'))
# ('75264', (438, 'siri1993'))
# ('75278', (72, 'prasoon singh'))
# ('75323', (37, 'elham'))
# ('75333', (70, 'khon'))
# ('73845', (358, 'praisethemoon'))
# ('75379', (988, 'dave'))
# ('75007', (502, 'benjhc'))
# ('75422', (46, 'hisptertuna'))
# ('75483', (122, 'nithin g a'))
# ('75523', (7049, 'beherit'))
# ('75546', (34, 'mimi'))
# ('75678', (463, 'hari charan vihari'))
# ('75748', (13, 'cpcd0y'))
# ('60068', (613, 'henry lidgley'))
# ('75982', (406, 'justabeginner'))
# ('75980', (146, 'kgutwin'))
# ('75988', (315, 'user3776738'))
# ('76074', (494, 'lei xun'))
# ('68200', (1483, 'anjali yadav'))
# ('44690', (256, 'cyberjoac'))
# ('76264', (241, 'patrick_weber'))
# ('76359', (350, 'jennifer darrouzet'))
# ('76530', (6025, 'machupicchu'))
# ('57323', (1650, 'notable1'))
# ('76641', (4678, 'lizzalice'))
# ('76658', (628, 'fsymao'))
# ('76156', (1935, 'vinit sutar'))
# ('76726', (184, 'lithiux'))
# ('76794', (807, 'fhaase'))
# ('76834', (149, 'vinay'))
# ('76923', (234, 'shiva'))
# ('77035', (2075, 'joao ferreira'))
# ('77170', (1451, 'timchap'))
# ('77244', (168, 'denis belov'))
# ('39011', (1147, 'oneextrafact'))
# ('77357', (565, 'idk'))
# ('77090', (39, 'samoncode'))
# ('77452', (46, 'nagnath'))
# ('77484', (1465, 'ysp'))
# ('77210', (542, 'ds_tn'))
# ('77557', (722, 'anton s'))
# ('75385', (284, 'maximilian janisch'))
# ('77572', (703, 'eric frey'))
# ('77663', (126, 'john ruby'))
# ('77677', (124, 'rajarshi'))
# ('75606', (92, 'harshtiwari'))
# ('77715', (445, 'mho2'))
# ('77739', (421, 'hang nguyen'))
# ('77752', (170, 'gabriel'))
# ('77788', (782, 'nonamemler'))
# ('77792', (936, 'user77792'))
# ('76429', (269, 'hey'))
# ('77851', (245, 'salman'))
# ('77877', (159, 'arsalan khan'))
# ('77625', (572, 'milad nazari'))
# ('69261', (51, 'dschori'))
# ('77904', (406, 'hryniu'))
# ('77933', (473, 'jedrzej'))
# ('78113', (211, 'karan singh'))
# ('78118', (117, 'debajyoti sengupta'))
# ('67110', (1252, 'karppmik'))
# ('78213', (95, 'gravity mass'))
# ('50796', (35, 'matt hamilton'))
# ('78345', (139, 'siraj qazi'))
# ('78354', (134, 'ilias papastratis'))
# ('78024', (1060, 'team'))
# ('78392', (214, 'arxoft'))
# ('75285', (382, 'angela'))
# ('78436', (587, 'jimsi'))
# ('78444', (263, 'josé lucas araújo dos santos'))
# ('78514', (143, 'stannis'))
# ('78586', (53, 'piya'))
# ('78602', (155, 'user209020'))
# ('71912', (2637, 'user3656142'))
# ('78686', (160, 'joey fueng'))
# ('78739', (84, 'user78739'))
# ('78766', (845, 'user48878'))
# ('78897', (719, 'joe_mind'))
# ('78910', (184, 'guohui li'))
# ('57328', (652, 'lila'))
# ('78987', (123, 'cookiedealer'))
# ('79059', (106, 'mohseen mulla'))
# ('79087', (255, 'rigo'))
# ('79100', (25, 'ellen voorhees'))
# ('79101', (34, 'saurabh dalakoti'))
# ('60445', (431, 'mrinal'))
# ('79231', (382, 'doflaminhgo'))
# ('79287', (812, 'patrieszka'))
# ('60622', (770, 'valeria'))
# ('79426', (225, 'rygel'))
# ('79451', (49, 'jason cheung'))
# ('79536', (298, 'brent cocu'))
# ('79559', (170, 'nicholas taylor'))
# ('79581', (75, 'mingu hyun'))
# ('14439', (116, 'nomorepen'))
# ('79617', (331, 'jarmunia'))
# ('49656', (236, 'john l.'))
# ('79659', (632, 'dr. h. lecter'))
# ('79595', (566, 'user4205580'))
# ('79699', (148, 'fereydoon barikzehy'))
# ('79762', (160, 'perelin'))
# ('79764', (81, 'mlnoob'))
# ('79761', (353, 'jonathan rolfsen'))
# ('79779', (482, 'jake fleisig'))
# ('78821', (140, 'a_the_kunal'))
# ('79815', (53, 'roberto vázquez lucerga'))
# ('79919', (212, 'r desgr'))
# ('79978', (179, 'msch8791'))
# ('79987', (91, 'user10487297'))
# ('80030', (43, 'ihf'))
# ('80085', (513, 'user882763'))
# ('8208', (153, 'yohan chung'))
# ('80272', (330, 'mrmulliner'))
# ('75145', (74, 'diya'))
# ('156', (5392, 'marco13'))
# ('173', (5595, 'wojciech walczak'))
# ('88', (466, 'igor bobriakov'))
# ('403', (1220, 'gallamine'))
# ('553', (519, 'lsdr'))
# ('534', (2181, 'trienism'))
# ('721', (72, 'user721'))
# ('737', (162, 'patlaf'))
# ('743', (370, 'lgylym'))
# ('50', (50, 'robert cartaino'))
# ('241', (491, 'tchakravarty'))
# ('922', (321, 'joews'))
# ('1147', (335, 'frost'))
# ('1208', (62, 'mcgoverntheory'))
# ('1237', (1061, 'stask'))
# ('1283', (511, 'user1158559'))
# ('1334', (95, 'soandos'))
# ('325', (1258, 'germcd'))
# ('2599', (189, 'dave kay'))
# ('2781', (7533, 'jamie'))
# ('2574', (1038, 'denpost'))
# ('2987', (92, 'jaidev deshpande'))
# ('3030', (135, 'user1913171'))
# ('3068', (765, 'rodrigo stv'))
# ('3101', (313, 'joy'))
# ('3203', (113, 'papacostas'))
# ('3216', (1191, 'jpcgandre'))
# ('3283', (718, 'paul k'))
# ('3361', (386, 'scortchi'))
# ('3390', (46, 'hnadiger'))
# ('3400', (560, 'eri0o'))
# ('3457', (977, 'user1269942'))
# ('3510', (591, 'david pepper'))
# ('3539', (133, 'brannon'))
# ('3586', (20, 'mieszko'))
# ('4619', (1452, 'user3634601'))
# ('4711', (150, 'i5vemula'))
# ('4794', (154, 'shamy'))
# ('5021', (947, 'batgirl'))
# ('5044', (1324, 'juanito'))
# ('2647', (3668, 'minu'))
# ('5165', (474, 'jc r'))
# ('5200', (719, 'eulerleibniz'))
# ('5268', (6806, 'cbeleites'))
# ('5280', (425, 'tris nefzger'))
# ('6451', (133, 'matsair'))
# ('6644', (527, 'knows not much'))
# ('6682', (315, 'deepraj kunnath'))
# ('7702', (190, 'user3142384'))
# ('6636', (520, 'user3256725'))
# ('6496', (1404, 'shahriar dadgar'))
# ('7786', (1873, 'max gibiansky'))
# ('8059', (307, 'striker'))
# ('8191', (3413, 'ee2dev'))
# ('536', (127, 'tilo.wiklund'))
# ('464', (313, 'erogol'))
# ('8296', (108, 'eflores89'))
# ('8381', (258, 'apstrk'))
# ('8392', (336, 'mcg256'))
# ('8605', (552, 'roboallen'))
# ('8662', (349, 'sai krishna gaddam'))
# ('8663', (97, 'sudo rm -rf slash'))
# ('8849', (509, 'closedloop'))
# ('8923', (53, 'ved'))
# ('8930', (38, 'yimihua'))
# ('8977', (81, 'mit student'))
# ('8987', (834, 'soren havelund welling'))
# ('8843', (131, 'd.castro'))
# ('8152', (3603, 'lennyklb'))
# ('9287', (91, 'user3848891'))
# ('9383', (20, 'spikedlatte'))
# ('9608', (322, 'akuryo'))
# ('9699', (181, 'poundsignonleft'))
# ('9700', (763, 'shainar'))
# ('9714', (398, 'fernando garcia'))
# ('9634', (1174, 'itdxer'))
# ('9766', (341, 'stochazesthai'))
# ('9880', (3138, 'josh w.'))
# ('9901', (159, 's2l'))
# ('9314', (5317, 'bartłomiej twardowski'))
# ('9958', (57, 'abhishek'))
# ('9974', (1682, 'djohnson'))
# ('10210', (828, 'spt025'))
# ('9039', (580, 'user5184'))
# ('10300', (177, 'osiris'))
# ('8999', (35, 'cuneytyvz'))
# ('10415', (33, 'matt sornson'))
# ('916', (91, 'ende'))
# ('10437', (51, 'übel yildmar'))
# ('10506', (622, 'jabberwockey'))
# ('10513', (1057, 'chris'))
# ('10536', (853, 'kayelow'))
# ('10549', (498, 'toy'))
# ('10810', (7720, 'beta'))
# ('10774', (89, 'user45668'))
# ('10832', (537, 'the3rdnotch'))
# ('10884', (503, 'duncan'))
# ('10894', (677, 'dr.fykos'))
# ('10608', (71, 'marcin'))
# ('11028', (279, 'andrea m'))
# ('11114', (101, 'joost'))
# ('12184', (453, 'stefanop'))
# ('12207', (40, 'hari'))
# ('12219', (122, 'epx'))
# ('226', (216, 'sushant-hiray'))
# ('8479', (346, 'david arenburg'))
# ('12265', (144, 'tim roberson'))
# ('12356', (205, 'ved gupta'))
# ('12516', (260, 'tofu_bacon'))
# ('12569', (109, 'jeez'))
# ('3592', (333, 'amir'))
# ('12663', (1018, 'johnnym'))
# ('12747', (722, 'jd87'))
# ('12827', (107, 'arschie'))
# ('12909', (1853, 'jérémie clos'))
# ('12905', (125, 'usεr11852'))
# ('10904', (2624, 'santoshi m'))
# ('13285', (16051, 'paparazzo'))
# ('9867', (3817, 'sds'))
# ('12290', (824, 'tguzella'))
# ('13593', (386, 'arb'))
# ('13772', (91, 'xyz'))
# ('13476', (58, 'hamideh'))
# ('13959', (228, 'ryan king'))
# ('12603', (3270, 'masl'))
# ('14030', (370, 'srobinson'))
# ('14048', (529, 'anton'))
# ('14327', (293, 'addem'))
# ('14392', (470, 'parox'))
# ('14353', (111, 'bg1850'))
# ('14636', (1723, 'pplonski'))
# ('15140', (217, 'hasan ali khan'))
# ('15253', (134, 'user6214'))
# ('15402', (372, 'ded'))
# ('13354', (181, 'brian ecker'))
# ('15412', (13008, 'nain'))
# ('15533', (4986, 'monica heddneck'))
# ('15599', (180, 'neuron'))
# ('15690', (1553, 'r. doe'))
# ('16040', (187, 'richar8086'))
# ('16050', (3999, 'ihadanny'))
# ('16203', (267, 'ravi chandra'))
# ('9351', (42, 'tachycline'))
# ('16337', (57, 'ds21'))
# ('16556', (188, 'lucasdavis500'))
# ('16601', (513, 'c0g'))
# ('16665', (51, 'lizk'))
# ('16818', (7755, 'jeffrey xiao'))
# ('16870', (287, 'fokhruz zaman'))
# ('17081', (308, 'саша'))
# ('17165', (373, 'thm14'))
# ('17462', (125, 'karthik'))
# ('17614', (1340, 'fabian'))
# ('14070', (2435, 'arnold klein'))
# ('18033', (47, 'rahul jain'))
# ('18058', (1359, 'new_analyst'))
# ('18179', (400, 'vinnief'))
# ('18184', (63, 'volodymyr fomenko'))
# ('18295', (124, 'bipero'))
# ('18429', (1261, 'twgardner2'))
# ('17771', (1292, 'bigdataumd'))
# ('18637', (310, 'abora'))
# ('18787', (7669, 'ole petersen'))
# ('18888', (38, 'feras odeh'))
# ('18992', (168, 'user18992'))
# ('19040', (58, 'sdream'))
# ('19162', (36, 'chris thompson'))
# ('19278', (561, 'luv agarwal'))
# ('20472', (169, 'divyum'))
# ('20647', (163, 'phil'))
# ('20655', (25, 'albert gao'))
# ('20667', (40, 'bryan - k0emt'))
# ('20722', (812, 'rohan sadale'))
# ('21024', (14519, 'hima varsha'))
# ('17585', (212, 'john'))
# ('14150', (1129, 'feynman27'))
# ('21376', (166, 'harold nuñez'))
# ('20995', (1072, 'josh'))
# ('21503', (548, 'blpasd'))
# ('13662', (2553, 'marvmind'))
# ('21619', (79, 'j__'))
# ('21642', (302, 'gshock'))
# ('21722', (119, 'ema nymton'))
# ('21755', (806, 'syzygyyy'))
# ('20290', (63, 'abdullah al imran'))
# ('21940', (87, 'user666'))
# ('17346', (199, 'jcrudy'))
# ('21992', (418, 'antorqs'))
# ('23090', (708, 'bobbyjohnsonog'))
# ('22054', (946, 'planaria'))
# ('23110', (201, 'jfive'))
# ('23127', (104, 'learnbyreading'))
# ('23159', (23196, 'skiddles'))
# ('23129', (93, 'krish'))
# ('23216', (427, 'cross_validater'))
# ('23245', (291, 'ganesh krishnan'))
# ('23330', (1852, 'frangoitia'))
# ('21990', (1100, 'jan sila'))
# ('16104', (499, 'karl'))
# ('17783', (487, 'thanos'))
# ('23802', (52, 'sergulaydore'))
# ('23847', (99, 'ceem'))
# ('24114', (246, 'signum'))
# ('8501', (7468, 'smci'))
# ('19220', (146, 'lucidyan'))
# ('24320', (341, 'serkan eryilmaz'))
# ('23144', (1130, "brian o'donnell"))
# ('24355', (305, 'krishna'))
# ('24760', (123, 'marcus-rosti'))
# ('24899', (89, 'justin martin'))
# ('24994', (482, 'толкачёв иван'))
# ('24467', (91, 'shoestringfries'))
# ('13977', (161, 'rhc'))
# ('25352', (237, 'foobar'))
# ('25366', (80, 'melvin roy'))
# ('25429', (37439, 'carlton banks'))
# ('25611', (1876, 'scottieb'))
# ('25681', (161, 'user57759'))
# ('25488', (785, 'emil'))
# ('25750', (954, 'tripleee'))
# ('25910', (24, 'fullmetalscientist'))
# ('25800', (3219, 'jkyh'))
# ('25236', (1667, 'louis maddox'))
# ('23614', (1255, 'amirouche'))
# ('26149', (158, 'bob'))
# ('26260', (134, 'abdullah danyal'))
# ('26288', (391, 'george_w_kush'))
# ('26350', (348, 'alew3'))
# ('26475', (5467, 'stefano nardo'))
# ('26562', (43485, 'timleathart'))
# ('26596', (16283, 'society of data scientists'))
# ('26766', (867, 'eric o lebigot'))
# ('26870', (244, 'mahtab'))
# ('27135', (711, 'daniel'))
# ('27196', (158, 'rimbaud_'))
# ('27356', (1272, 'timekeeper'))
# ('27551', (701, 'christian safka'))
# ('27625', (62, 'amon 1994'))
# ('24996', (993, 'nikolas rieble'))
# ('27706', (513, 'dasha bazueva'))
# ('27756', (286, 'madison silver'))
# ('27780', (263, 'paul siegel'))
# ('27796', (162, 'michael'))
# ('27896', (111, 'bob van luijt'))
# ('28011', (535, 'benedikt s. vogler'))
# ('28081', (72, 'roosh'))
# ('28138', (552, 'yusuf'))
# ('28208', (346, 'j. lerman'))
# ('28222', (492, 'j.guillaumin'))
# ('17640', (518, 'j_heads'))
# ('15464', (517, 'gga'))
# ('28669', (54, 'gman9732'))
# ('28917', (789, 'melih'))
# ('27873', (813, 'prayalankar'))
# ('29234', (807, 'canardini'))
# ('29315', (148, 'actaeonis'))
# ('29346', (536, 'nibby'))
# ('29533', (148, 'gourab das'))
# ('29606', (366, 'zfb'))
# ('29656', (258, 'ruppesh nalwaya'))
# ('29735', (137, 'alec matusis'))
# ('29790', (1018, 'coderdave'))
# ('29841', (291, 'juliosergio'))
# ('29900', (76, 'sinjan chakraborty'))
# ('29922', (55, 'n.f.k. emmanuel'))
# ('29939', (473, 'iain reid'))
# ('30099', (281, 'asampat3090'))
# ('30473', (395, 'hanspeterloft'))
# ('30481', (148, 'matt brems'))
# ('29157', (5711, 'vikram murthy'))
# ('30502', (92, 'george'))
# ('30578', (7463, 'vivek kalyanarangan'))
# ('31154', (636, 'henry'))
# ('31275', (83, 'pgrenholm'))
# ('31346', (973, 'astroman'))
# ('31399', (1140, 'eric ed lohmar'))
# ('31538', (438, 'colby'))
# ('31618', (53, 'kevinfergs'))
# ('31663', (91, 'deepak'))
# ('31667', (125, 'nikkou'))
# ('30884', (377, 'mohanad kaleia'))
# ('32130', (426, 'vineet sunkavalli'))
# ('30335', (6214, 'generic_user'))
# ('32280', (7890, 'aidan.plenert.macdonald'))
# ('32307', (1278, 'lisa888'))
# ('32542', (110, 'mani'))
# ('32580', (1002, 'paul benn'))
# ('32701', (127, 'max newsite'))
# ('32723', (279, 'aleksey nozdryn-plotnicki'))
# ('32791', (397, 'bendundee'))
# ('32946', (186, 'xu yuanyuan'))
# ('33018', (1267, 'blazej kowalski'))
# ('27265', (170, 'elecjack'))
# ('33110', (332, 'waseem adil'))
# ('33130', (137, 'payas pandey'))
# ('33202', (10007, 'kbrose'))
# ('33407', (93, 'ichrak lafram'))
# ('26105', (198, 'md. rayhanul islam'))
# ('33447', (812, 'albarji'))
# ('33587', (365, 'max33587'))
# ('33612', (67, 'user3781426'))
# ('8904', (95, 'lbenitesanchez'))
# ('33135', (871, 'introspectivemathematics'))
# ('33993', (80, 'alexandru daia'))
# ('34042', (3058, 'user34042'))
# ('34160', (183, 'brad'))
# ('33301', (389, 'minkyung'))
# ('34269', (33699, 'djib2011'))
# ('35570', (538, 'b10hazard'))
# ('35718', (1767, 'yash katariya'))
# ('35738', (255, 'axgryndr'))
# ('35656', (229, 'majid abdolshah'))
# ('35772', (130, 'exp5logmingus'))
# ('35812', (2198, 'asdfkjasdfjk'))
# ('2862', (196, 'sparc_spread'))
# ('37406', (2034, 'user37406'))
# ('37407', (2583, 'user8384788'))
# ('35917', (489, 'johk95'))
# ('37648', (533, 'narahari b m'))
# ('37666', (79, 'dhaval thakkar'))
# ('37830', (49, 'metin say'))
# ('37847', (287, 'john'))
# ('37915', (207, 'ashutosh khare'))
# ('23402', (516, 'quintumnia'))
# ('38112', (224, 'acyclicsalmon'))
# ('38216', (325, 'miri'))
# ('33980', (200, 'matt s'))
# ('38272', (329, 'rumtscho'))
# ('32424', (90, 'thewiz'))
# ('38426', (138, 'girish arora'))
# ('16581', (854, 'arnab biswas'))
# ('3117', (1123, 'peterh'))
# ('37808', (2005, 'mimi müller'))
# ('38583', (104, 'd.baum'))
# ('32762', (838, 'abhishek sharma'))
# ('38717', (134, 'kasa'))
# ('38960', (160, 'pavelexpertov'))
# ('39236', (179, 'ryuzakinho'))
# ('39258', (326, 'anush prem'))
# ('39325', (290, 'wayne bruce'))
# ('8877', (1, 'animuson'))
# ('33600', (38, 'dexter'))
# ('39081', (1358, 'ziofil'))
# ('39533', (247, 'mjosh'))
# ('39577', (126, 'frank98'))
# ('39599', (156, 'emperorspride188'))
# ('39715', (561, 'pingu2k4'))
# ('39569', (142, 'denis dollfus'))
# ('39982', (447, 'amin sh'))
# ('39993', (99, 'dmbc'))
# ('16487', (44, 'ksopyla'))
# ('40180', (89, 'arthurdent'))
# ('40210', (20, 'alexandre meyer'))
# ('40263', (289, 'mich'))
# ('15384', (128, 'roman'))
# ('40491', (452, 'francesca tosi'))
# ('40653', (110, 'juanu haedo'))
# ('40656', (375, 'elder santos'))
# ('14284', (98, 'gabe'))
# ('10640', (9153, 'nbro'))
# ('40813', (154, 'abrar'))
# ('40818', (190, 'marvasti'))
# ('40857', (1045, 'jessie'))
# ('40965', (546, 'kiri_23'))
# ('41254', (1389, 'meraxes'))
# ('41397', (105, 'walid belrhalmia'))
# ('41410', (141, 'hming9527'))
# ('41557', (6693, 'shiva'))
# ('40075', (135, 'dman'))
# ('41710', (194, 'justin'))
# ('41741', (132, 'rishi swethan'))
# ('16416', (161, 'flow'))
# ('38351', (756, 'avinash'))
# ('42031', (362, 'user42031'))
# ('6488', (322, 'elexhobby'))
# ('2532', (226, 'dan'))
# ('42275', (901, 'joseph'))
# ('40552', (262, 'mrk'))
# ('42401', (85, 'taamer'))
# ('31818', (158, 'jan trienes'))
# ('42535', (1505, 'yves'))
# ('42627', (98, 'erny daniels'))
# ('41919', (225, 'balleny'))
# ('42730', (710, 'iamlion12'))
# ('42832', (813, 'eugval'))
# ('42854', (190, 'corey kennedy'))
# ('1037', (146, 'kevin h. lin'))
# ('42613', (952, 'eran moshe'))
# ('43141', (4013, 'snowparrot'))
# ('43474', (1079, 'alex'))
# ('43525', (46, 'tbnsilveira'))
# ('43714', (521, 'zahi azmi'))
# ('43812', (67, 'ghassan bati'))
# ('43833', (136, 'bing'))
# ('30686', (389, 'ashish sahu'))
# ('43958', (195, 'sathindu kavneth'))
# ('44088', (167, 'alberto'))
# ('44136', (427, 'shiva'))
# ('31603', (329, 'rexcirus'))
# ('44207', (88, 'saulgoodman'))
# ('44211', (312, 'scared andconfused'))
# ('44340', (887, 'therzog'))
# ('44424', (988, 'nicola'))
# ('44573', (107, 'dee'))
# ('44581', (285, 'vranvs'))
# ('44647', (66, 'daruri'))
# ('40928', (119, 'jonjup'))
# ('45018', (2462, 'ahsan nawaz'))
# ('45269', (184, 'levi botelho'))
# ('45292', (529, 'michael wakileh'))
# ('45423', (220, 'sourav roy'))
# ('41615', (761, 'czechnology'))
# ('45450', (585, 'shine on you crazy diamond'))
# ('45594', (270, 'dnup1092'))
# ('45643', (415, 'fonjeekay'))
# ('45675', (23, 'faaeq'))
# ('45809', (727, 'chris'))
# ('45814', (29, 'michael laster'))
# ('45963', (138, 'markus rh'))
# ('46055', (3520, 'dpascal'))
# ('46272', (111, 'jeffrey'))
# ('46307', (1981, 'vaslo'))
# ('46317', (1280, 'james'))
# ('46327', (975, 'li x'))
# ('46426', (373, 'zach'))
# ('46546', (1343, 'keith dowd'))
# ('46587', (572, 'sachin'))
# ('46628', (153, 'rajul mittal'))
# ('39076', (7964, 'ihavadoubt'))
# ('39911', (453, 'aporil'))
# ('40791', (776, 'krishnab'))
# ('47048', (228, 'user5919369'))
# ('46625', (148, 'olisteadman'))
# ('40057', (46, 'edo'))
# ('47260', (46, 'mutyalama'))
# ('47339', (2807, 'arnjac'))
# ('33960', (34, 'nishul tomar'))
# ('47832', (13268, 'duttaa'))
# ('47883', (915, 'nemanja boskovic'))
# ('47242', (172, 'nk7983'))
# ('48970', (232, 'f.saint'))
# ('49008', (120, 'twdude'))
# ('46898', (253, 'indika k'))
# ('49058', (143, 'wlaura'))
# ('47730', (776, 'benedict k.'))
# ('49378', (135, 'ceasar bautista'))
# ('49226', (1876, 'ripstein'))
# ('49491', (427, 'sc20d'))
# ('41656', (581, 'swas'))
# ('49454', (2445, 'siladittya'))
# ('49624', (180, 'khaldi'))
# ('45216', (821, 'xia'))
# ('46800', (67, 'janmejaya nanda'))
# ('46452', (132, 'frank'))
# ('43193', (6929, 'shirish kulhari'))
# ('50156', (45, 'user3607644'))
# ('24883', (10706, 'aaditya ura'))
# ('50338', (307, 'thiago'))
# ('50315', (2579, 'reem oo'))
# ('50391', (51, 'ali hassan'))
# ('50419', (69, 'miska'))
# ('50449', (3118, 'uharsha33'))
# ('50489', (484, 'staffofsage'))
# ('26674', (920, 'alpha_989'))
# ('50555', (72, 'niels krogh'))
# ('50719', (128, 'steven schenk'))
# ('50720', (251, 'zubair riaz'))
# ('50852', (3261, 'chetna bansal'))
# ('50944', (67, 'paul wiesemann'))
# ('51002', (85, 'mmnormyle'))
# ('51031', (44, 'azza ousji'))
# ('51065', (211, 'irene'))
# ('51192', (172, 'rohit jere'))
# ('50402', (173, 'christian'))
# ('50247', (126, 'fateh'))
# ('26581', (101, 'noob8374'))
# ('51241', (370, 'ram seshadri'))
# ('51297', (43, 'joshua day'))
# ('51369', (1391, 'karthiks'))
# ('51408', (467, 'saul lugo'))
# ('51446', (386, 'rockyraw'))
# ('50668', (1515, 'miroli'))
# ('51487', (242, 'naive231'))
# ('9273', (970, 'lpt'))
# ('51993', (291, 'aleksejs fomins'))
# ('10654', (93, '2daaa'))
# ('52087', (205, 'eyio'))
# ('52191', (434, 'michaelmuller'))
# ('52283', (79, 'simonll'))
# ('52344', (175, 'stkvtflw'))
# ('23334', (2542, 'nutle'))
# ('52460', (306, 'j rodr'))
# ('52476', (264, 'beginner'))
# ('52590', (87, 'garbage00'))
# ('52603', (1761, 'xavier bourret sicotte'))
# ('52692', (245, 'zeeshan mahmud'))
# ('52759', (188, 'ashishds'))
# ('52852', (165, 'yiannis ath'))
# ('32120', (250, 'tarashypka'))
# ('50353', (186, 'sina'))
# ('52981', (111, 'user2333453'))
# ('39673', (132, 'floriangd'))
# ('53352', (1043, 'qubix'))
# ('53411', (361, 'plopd'))
# ('53439', (1049, 'ashunigion'))
# ('53600', (147, 'laughing man'))
# ('30137', (285, 'cjmec'))
# ('53885', (327, 'david masters'))
# ('54031', (114, 'diaton'))
# ('32569', (740, 'neuronq'))
# ('54140', (58, 'chintan-p-bhatt'))
# ('54262', (163, 'tanmay kajbaje'))
# ('54268', (161, 'karim manaouil'))
# ('54277', (1161, 'mathews24'))
# ('54450', (191, 'yash gandhe'))
# ('54623', (4844, 'fabiospaghetti'))
# ('32240', (186, 'alexander chervov'))
# ('54658', (306, 'alex kaczynski'))
# ('54715', (777, 'ali250'))
# ('54756', (101, 'hanif ansari'))
# ('54799', (1368, 'jakes'))
# ('54899', (508, 'lucidbrot'))
# ('45179', (215, 'fakher mokadem'))
# ('54929', (1692, 'bear'))
# ('54992', (1910, 'electric head'))
# ('44560', (144, 'tina j'))
# ('55142', (111, 'erudite'))
# ('56195', (3821, 'bonez001'))
# ('49504', (55, 'tejas bawaskar'))
# ('56296', (141, 'bilal alam'))
# ('56322', (69, 'hotips'))
# ('50356', (215, 'lwb'))
# ('56329', (979, 'macaw_9227'))
# ('56355', (830, 'azza abidi'))
# ('52762', (506, 'user12547645'))
# ('56653', (125, 'aakash choubey'))
# ('56800', (701, 'gi.joe'))
# ('56811', (137, 'joe king'))
# ('56825', (269, 'jan parzydło'))
# ('57019', (14757, 'rawia sammout'))
# ('57033', (1557, 'nicholas albion'))
# ('57052', (135, 'aaron pham'))
# ('57076', (368, 'ajeje'))
# ('57158', (282, 'shahrzad amoozegar'))
# ('57175', (45, 'jim meyer'))
# ('57229', (469, 'konsta peltoniemi'))
# ('57231', (1161, 'george'))
# ('57283', (225, 'zrakk'))
# ('57326', (406, 'to_the_sun'))
# ('57527', (1070, 'i know nothing'))
# ('57560', (526, 'earthgecko'))
# ('57472', (58, 'muaaz arif'))
# ('57610', (3229, 'tarlan ahad'))
# ('52768', (271, 'stav bodik'))
# ('44015', (220, 'sergey kravchenko'))
# ('57704', (4510, 'volta'))
# ('57729', (32, 'cuser'))
# ('57757', (99, 'roy z'))
# ('56734', (125, 'wayde herman'))
# ('57825', (992, 'aac'))
# ('57871', (1205, 'elemolotiv'))
# ('57613', (893, 'stephopolis'))
# ('58067', (408, 'dodo'))
# ('58122', (871, 'ashwini'))
# ('58193', (448, 'justas b.'))
# ('57901', (4166, 'laure d'))
# ('58380', (1063, 'aman dalmia'))
# ('58398', (191, 'pablo gonzalez'))
# ('58432', (1198, 'tkj80'))
# ('58598', (304, 'pablo lopez alvarez'))
# ('58646', (237, 'jonathan foldager'))
# ('57596', (130, 'snow'))
# ('58831', (41, 'gabe'))
# ('47145', (424, 'divyang vashi'))
# ('59015', (335, 'swistack'))
# ('59025', (345, 'dmitrij kultasev'))
# ('58761', (166, 'roshan'))
# ('59330', (104, 'andrew'))
# ('59390', (75, 'brandon'))
# ('34256', (138, 'aminevsaziz'))
# ('59428', (323, 'vickysuraj'))
# ('59456', (73, 'bode '))
# ('28530', (350, 'hellter'))
# ('59484', (193, 'mihkel l.'))
# ('59517', (155, 'kira bulatov'))
# ('59600', (110, 'lonesomerider'))
# ('59623', (190, 'guyko'))
# ('59693', (3331, 'vincent b. lortie'))
# ('59671', (871, 'suman'))
# ('59749', (599, 'jawad yousuf'))
# ('59785', (139, 'nate raw'))
# ('59838', (40, 'p126018 ali raza'))
# ('59874', (193, 'teddy ward'))
# ('59918', (281, 'syed amer'))
# ('60000', (381, 'stats_nerd'))
# ('60069', (261, 'paloma manzano'))
# ('60157', (56, 'user60157'))
# ('60115', (996, 'myath'))
# ('56923', (213, 'schrodingercat'))
# ('60184', (1415, 'induction601'))
# ('60257', (63, 'bharath chandra'))
# ('60351', (1063, 'sanjaya panigrahy'))
# ('60368', (74, 'abdaoui amine'))
# ('60172', (238, 'jonathan eslava'))
# ('60654', (225, 'user_1234'))
# ('49422', (5251, 'deep'))
# ('60905', (296, 'vadiraj joshi'))
# ...
# ('49104', (257, 'jepsilon'))
# ('47858', (315, 'aechlys'))
# ('49217', (2977, 'john rauser'))
# ('49382', (82, 'utkarsh sah'))
# ('49426', (84, 'isarandi'))
# ('49483', (80, 'kiran'))
# ('49354', (288, 'youngam'))
# ('49517', (4769, 'maurocomi'))
# ('49597', (280, 'clint'))
# ('49603', (176, 'shubham jain'))
# ('49667', (206, 'viktor'))
# ('49779', (46, 'asdadas'))
# ('37172', (3196, 'brendan hill'))
# ('50262', (214, 'julian kurz'))
# ('50810', (136, 'hennyko'))
# ('50872', (131, 'stwykd'))
# ('50963', (175, 'hsyeda'))
# ('51003', (529, 'michael'))
# ('51037', (990, 'veganhunter'))
# ('42829', (1707, 'ashoffire'))
# ('51060', (122, 'marimo'))
# ('51211', (214, 'n. kim'))
# ('51243', (44, 'jeffhu'))
# ('51248', (235, 'alex'))
# ('51305', (65, 'user51305'))
# ('51344', (471, 'jaiprakash prajapati'))
# ('51343', (404, 'buechel'))
# ('50583', (195, 'yuriy nazarov'))
# ('51459', (345, 'thiago melo'))
# ('51506', (378, 'rob'))
# ('51624', (3017, 'strabonio'))
# ('46174', (387, 'houcine amraoui'))
# ('51652', (105, 'salsa_virginia'))
# ('51760', (31, 'hungrybird'))
# ('51788', (74, 'shazma khan'))
# ('51823', (155, 'usman malik'))
# ('51829', (65, 'xman'))
# ('51872', (89, 'lisa'))
# ('51908', (62, 'thepen'))
# ('51926', (35, 'nasri'))
# ('51931', (1570, 'joker123'))
# ('52012', (218, 'bianster'))
# ('31106', (147, 'ma3oun'))
# ('52077', (89, 'shiv'))
# ('26525', (1167, 'sahar milis'))
# ('52082', (445, 'saicharan'))
# ('22074', (1803, 'mateusz konopelski'))
# ('52241', (1331, 'reguser'))
# ('52342', (159, 'rotem shalev'))
# ('52382', (136, 'michael brundage'))
# ('52439', (82, 'karan malhotra'))
# ('52444', (467, 'montecristo'))
# ('52473', (52, 'anshula acharyya'))
# ('52619', (178, 'beharrlich'))
# ('52623', (5980, 'adam hendry'))
# ('52684', (158, 'leo jiang'))
# ('42984', (214, 'k v vijay girish'))
# ('42498', (2622, 'divyanshu shekhar'))
# ('44617', (372, 'vachan lm'))
# ('52811', (85, 'simone genta'))
# ('52877', (152, 'shell'))
# ('52941', (195, 'chris reagen'))
# ('28668', (137, 'cbake'))
# ('30482', (291, 'tool'))
# ('53223', (850, 'frank c jones'))
# ('53233', (374, 'jroakes'))
# ('38616', (942, 'jason aller'))
# ('53361', (6051, 'jazz'))
# ('53504', (1582, 'avipasup'))
# ('53516', (3950, 'chris'))
# ('33166', (510, 'kuanb'))
# ('53732', (672, 'isthemailmanrecursive'))
# ('53735', (609, 'baxter'))
# ('7736', (140, 'aamir23'))
# ('53824', (335, 'yashwanth kumar pamidimukkala'))
# ('53988', (69, 'artem'))
# ('54017', (32, 'rafael padilla'))
# ('53940', (4167, 'rlave'))
# ('54170', (207, 'r schumacher'))
# ('54353', (535, 'elliot '))
# ('54401', (2199, 'flajt'))
# ('54418', (314, 'seong su  byeon'))
# ('54420', (189, 'harsh'))
# ('54442', (1191, 'manza'))
# ('31571', (157, 'daniel beasley'))
# ('54653', (117, 'sajid khan'))
# ('49375', (2358, 'richard careaga'))
# ('54749', (114, 'sfw1'))
# ('38305', (123, 'jkds'))
# ('53020', (79, 'irishabha'))
# ('54961', (149, 'glen'))
# ('54981', (137, 'user3629077'))
# ('55001', (776, 'saleh'))
# ('55097', (35, 'erdal.karaca'))
# ('37792', (360, 'h.z.'))
# ('56231', (165, 'yashas'))
# ('33832', (81, 'user234725'))
# ('56339', (497, 'rajeshs'))
# ('56344', (1168, 'srikrishna'))
# ('56401', (520, 'hyunsu jeong'))
# ('56410', (304, 'hfaila'))
# ('56421', (285, 'benjamin toueg'))
# ('56508', (279, 'm. ahmad'))
# ('56536', (257, 'giannis m. bakagiannis'))
# ('56726', (235, 'littlebenlittle'))
# ('56765', (199, 'rmacqueen'))
# ('56846', (697, 'carch'))
# ('56883', (482, 'triples'))
# ('56904', (206, 'user650261'))
# ('54562', (135, 'rahul raj'))
# ('56977', (164, 'lior messinger'))
# ('56983', (1657, 'karim mohamed hasebou'))
# ('57009', (82, 'mohamed bahdine'))
# ('57291', (589, 'henrik berg'))
# ('57422', (146, 'james mallett'))
# ('57456', (344, 'trijoco'))
# ('57477', (152, 'saper0'))
# ('57499', (72, 'femi'))
# ('57549', (59, 'user57549'))
# ('57586', (422, 'user3079474'))
# ('46523', (895, 'johnathan brown'))
# ('54509', (1998, 'stefanlopez'))
# ('15692', (176, 'eugene yan'))
# ('57733', (171, 'cesar'))
# ('57771', (49, 'pranav vempati'))
# ('57777', (2346, 'richard.r'))
# ('57780', (266, 'user1725306'))
# ('28125', (654, 'secespitus'))
# ('57804', (368, 'seyyed a.'))
# ('57797', (115, 'siddharth'))
# ('57837', (514, 'thenationalsarcasmsociety'))
# ('54743', (224, 'sunil4data'))
# ('57912', (88, 'hajar homayouni'))
# ('57953', (148, 'ilia kandrashou'))
# ('57732', (320, 'abhisek'))
# ('58140', (2321, 'bdillan'))
# ('58191', (211, 'tidylobster'))
# ('58306', (982, 'giordano'))
# ('58314', (113, 'as91'))
# ('58400', (851, 'melanie a'))
# ('58508', (427, 'random user'))
# ('58540', (116, 'anis fatnassi'))
# ('58617', (1787, 'okossial'))
# ('58155', (3797, 'myron leskiv'))
# ('58741', (316, 'carl'))
# ('56964', (153, 'maruti goswami'))
# ('57454', (1700, 'alerra'))
# ('59027', (759, 'soroush'))
# ('54528', (272, 'donald battle'))
# ('46265', (11567, 'x-rw'))
# ('59374', (142, 'user2445254'))
# ('44648', (964, 'nils schlüter'))
# ('39380', (304, 'ayush chaurasia'))
# ('59507', (40, 'user3452134'))
# ('53025', (465, 'stenga'))
# ('37783', (320, 'arslán'))
# ('59611', (251, 'poonam ligade'))
# ('59701', (1621, 'minila s'))
# ('4862', (125, 'slymore'))
# ('59345', (44, 'stephane bersier'))
# ('60024', (85, 'tejas'))
# ('60030', (199, 'leron julian'))
# ('60092', (127, 'ali akber'))
# ('60105', (6519, 'user_6396'))
# ('60468', (386, 'bhawesh chandola'))
# ('29586', (79, 'johnaphun'))
# ('60700', (38, 'geeksamu'))
# ('60946', (435, 'zhefrench'))
# ('61003', (168, 'vic wolda'))
# ('60985', (545, 'rahul_saini'))
# ('61062', (201, 'piyush singh'))
# ('61109', (145, 'programmingrookie'))
# ('61118', (254, 'bombburper'))
# ('61180', (735, 'arun ponnusamy'))
# ('61189', (148, 'dnivog'))
# ('61486', (615, 'shahzeb haider'))
# ('61440', (431, 'thecuriouslycodingfoxah'))
# ('61663', (229, 'asael aiken'))
# ('61809', (706, 'b. erickson'))
# ('61817', (165, 'rishabh baid'))
# ('61821', (28, 'naresh mungpara'))
# ('61023', (938, 'joel carneiro'))
# ('44557', (286, 'leon'))
# ('60967', (147, 'gregory rut'))
# ('61658', (86, 'masterwizard'))
# ('62294', (411, 'kerem fidan'))
# ('62358', (248, 'aditya kadrekar'))
# ('62393', (1104, 'marinos zagkotsis'))
# ('62412', (364, 'lucas'))
# ('60636', (776, 'james flash'))
# ('62515', (368, 'rahul'))
# ('62695', (84, 'deependra singh '))
# ('62743', (1574, 'whelibeiren'))
# ('62987', (83, 'noel'))
# ('63031', (2755, 'random nerd'))
# ('63196', (3157, 'aalok'))
# ('63282', (255, 'desmond'))
# ('33138', (296, 'wayne thompson'))
# ('62867', (612, 'marco fumagalli'))
# ('63468', (420, 'manish'))
# ('61177', (247, 'codemonkey'))
# ('41206', (227, 'thetechguy'))
# ('63856', (1531, 'alexbrini'))
# ('63421', (95, 'shetty'))
# ('64126', (516, 'e. dem '))
# ('54024', (259, 'saias'))
# ('64185', (61, 'b mathunjwa'))
# ('64321', (114, 'falcon lover'))
# ('64356', (3020, 'charlesg'))
# ('64394', (70, 'bastian'))
# ('63445', (1672, 'ludecan'))
# ('64498', (104, 'ted'))
# ('62950', (387, 'peran bray'))
# ('64639', (180, 'francisco del valle bas'))
# ('64700', (710, 'opifex'))
# ('64720', (202, 'arpit kathuria'))
# ('64805', (223, 'karanv.10111'))
# ('59101', (407, 'francesco boi'))
# ('52418', (150, 'dheerajkhanna'))
# ('64963', (80, 'mip'))
# ('64969', (313, 'krince liu'))
# ('65009', (49, 'sebastian'))
# ('18170', (385, 'aman tandon'))
# ('65090', (244, 'smörkex'))
# ('64781', (413, 'jin hao'))
# ('65300', (4682, 'yash mehta'))
# ('65384', (233, 'rasool ghafari'))
# ('40392', (1310, 'peter k.'))
# ('65640', (62, 'sabir ullah'))
# ('49151', (72, 'jacob crockett'))
# ('65730', (303, 'rebecca swab'))
# ('65809', (1398, 'zephyr'))
# ('65266', (104, 'vishal bajaj'))
# ('65698', (1948, 'urbanofonseca'))
# ('62759', (118, 'gopal kalpande'))
# ('54265', (76, 'niklas'))
# ('65985', (6557, 'zwang'))
# ('66003', (46, 'dave nguyen'))
# ('66045', (252, 'xqua'))
# ('66063', (171, 'vinaykrishna'))
# ('66101', (142, 'adrian perez'))
# ('66115', (1628, 'mad_dash2'))
# ('66126', (380, 'jim'))
# ('65834', (1565, 'balasubrahmanyam ira'))
# ('66245', (163, 'lwi'))
# ('66484', (43, 'user66484'))
# ('66485', (49, 'user66485'))
# ('64083', (124, 'sri'))
# ('66535', (1099, 'rekt'))
# ('66612', (1009, 'eugen'))
# ('66664', (220, 'balki'))
# ('66753', (417, 'yesiamabdul'))
# ('66905', (55, 'shubham agrawal 4-yr btech che'))
# ('66911', (302, 'ds_guy'))
# ('66984', (126, 'boughrara '))
# ('67002', (71, 'ashwani kumar'))
# ('66861', (350, 'gafortiby'))
# ('67001', (143, 'jessica lee'))
# ('67081', (166, 'peter'))
# ('67172', (141, 'steve'))
# ('67245', (171, 'peacemaker'))
# ('67310', (44, 'james smith'))
# ('67277', (135, 'khush'))
# ('67345', (121, 'sam'))
# ('67386', (273, 'michael bolton'))
# ('67383', (787, 'micsza'))
# ('64039', (136, 'joshua terrill'))
# ('67474', (301, 'arjun arora'))
# ('67602', (1946, 'heisenbug'))
# ('67096', (714, 'ciaran kelly'))
# ('67679', (157, 'ravi kumar'))
# ('62069', (957, 'franco piccolo'))
# ('65409', (588, 'stan0'))
# ('67908', (155, 'chirag gupta'))
# ('67605', (10810, 'user145959'))
# ('51854', (366, 'nixon'))
# ('68006', (9718, 'vis7'))
# ('68037', (123, 'amartin'))
# ('68177', (207, 'danielg'))
# ('68229', (77, 'supradha -'))
# ('68259', (668, 'billy'))
# ('68294', (318, 'ahsan umar'))
# ('68306', (787, 'twoot'))
# ('68416', (125, 'eduardo santana da silva'))
# ('68439', (49, 'abhishek sharma'))
# ('64208', (194, 'mulugeta weldezgina'))
# ('66764', (204, 'prathmesh savale'))
# ('68573', (307, 'ashar'))
# ('68586', (2874, 'harsha reddy'))
# ('68575', (94, 'justice_lords'))
# ('68564', (177, 'a-ar'))
# ('68817', (95, 'user3770700'))
# ('68678', (137, 'annalise azzopardi'))
# ('68848', (167, 'edna'))
# ('45705', (37, 'wajdan ali'))
# ('46921', (205, 'mehraban'))
# ('65375', (1479, 'user9317212'))
# ('68908', (2063, 'gebbissimo'))
# ('68869', (1862, 'itay bachar'))
# ('69038', (140, 'jarvispennyworth'))
# ('63544', (160, 'tomas piaggio'))
# ('69194', (203, 'user69194'))
# ('69272', (132, 'gaurav'))
# ('69324', (118, 'saisubrahmanyam janapati'))
# ('59389', (356, 'sank_be'))
# ('69488', (132, 'thunfische'))
# ('67782', (119, 'green'))
# ('69546', (263, 'user3116297'))
# ('17356', (2888, 'eli korvigo'))
# ('69606', (171, 'dipak narayanan'))
# ('69686', (108, 'asahi kibou'))
# ('69689', (1726, 'sympa'))
# ('69776', (962, 'saurbh'))
# ('69789', (138, 'johndoe'))
# ('69822', (38985, 'blenz'))
# ('69884', (371, 'himadri'))
# ('69942', (4802, 'andrew cheong'))
# ('70053', (198, 'bilal alauddin'))
# ('63488', (225, 'diogo santos'))
# ('64689', (399, 'guillaume'))
# ('70243', (1198, 'radioactive'))
# ('70316', (57, 'globetroter'))
# ('70387', (29, 'ram'))
# ('66863', (925, 'baxx'))
# ('70414', (130, 'danyl denysenko'))
# ('70709', (897, 'carl dombrowski'))
# ('70785', (62, 'neurokinetikz'))
# ('70863', (372, 'pythonguest'))
# ('70865', (179, 'martin'))
# ('70910', (884, 'b.k'))
# ('70958', (625, 'r. cox'))
# ('71093', (592, 'seed.of.apricot'))
# ('71189', (254, 'ita'))
# ('71275', (235, 'saurabh daalia'))
# ('71281', (26, 'kartik singh'))
# ('71282', (124, 'fercaneo'))
# ('71297', (5194, 'fractalnature'))
# ('71418', (163, 'daxterss'))
# ('71464', (1107, 'kartikeya sharma'))
# ('64025', (37, 'abishekh kc'))
# ('71504', (292, 'babak.abad'))
# ('71511', (727, 'darklink9110'))
# ('71349', (229, 'nicklovn'))
# ('71605', (200, 'reneraab'))
# ('71667', (44, 'dmahata'))
# ('71787', (103, 'satoukibi'))
# ('71860', (139, 'raki lachraf'))
# ('71863', (34, 'dfvc'))
# ('71974', (267, 'siddharth singh'))
# ('73064', (358, 'migara'))
# ('73068', (445, 'pedro vieira'))
# ('73125', (600, 'siddharth vij'))
# ('73150', (8799, 'alex f'))
# ('73254', (162, 'yuval asher'))
# ('73086', (136, 'dick'))
# ('73293', (421, 'user2726192'))
# ('73351', (447, 'lmp'))
# ('21844', (67, 'vinita'))
# ('73401', (5440, 'mbax2ak3'))
# ('73413', (627, 'mohammad raoofnia'))
# ('73406', (2127, 'susovan.bv'))
# ('73423', (1301, 'user73423'))
# ('73442', (367, '林彥良'))
# ('73475', (68, 'adjr2'))
# ('73547', (971, 'brennn'))
# ('73612', (439, 'benjamin coffer'))
# ('73621', (354, 'kirito solo'))
# ('36964', (107, 'schoon'))
# ('73678', (1214, 'ashu'))
# ('73676', (151, 'tomonso ejang'))
# ('73665', (170, 'jsh'))
# ('73740', (1571, 'mr prof'))
# ('73821', (297, 'zhenkai'))
# ('60379', (3868, 'optimizor'))
# ('73654', (418, "i_don't_code"))
# ('66131', (170, 'ava'))
# ('73663', (482, 'display name'))
# ('73934', (1676, 'miusixo'))
# ('73970', (316, 'vinodetrx'))
# ('52273', (131, 'david lebauer'))
# ('58385', (202, 'bikashg'))
# ('71442', (69105, 'peter'))
# ('73636', (5608, 'milan'))
# ('52275', (1071, 'arnuld'))
# ('74094', (283, 'mozza'))
# ('74105', (132, 'edward weinert'))
# ('74108', (58, 'raghavendra g'))
# ('34279', (926, 'm2x'))
# ('73332', (476, 'nairboon'))
# ('74242', (30, 'fodma1'))
# ('74295', (128, 'm.vela'))
# ('73981', (1019, 'marco caglia'))
# ('64377', (25411, 'erwan'))
# ('74366', (201, 'kayak'))
# ('74396', (208, 'martin pichler'))
# ('74460', (1510, 'cauder'))
# ('74471', (357, 'cbusbus'))
# ('73559', (38, 'harsath'))
# ('63365', (419, 'dyez'))
# ('74581', (279, 'ericathaufe'))
# ('74620', (297, 'joão guerreiro'))
# ('63780', (284, 'pratham'))
# ('16446', (107, 'yasmin'))
# ('74850', (900, 'uncountably-infinite'))
# ('70101', (42, 'akash basudevan'))
# ('56257', (251, 'charles_de_montigny'))
# ('75090', (169, 'ankit patel'))
# ('75199', (101, 'abhishek anand'))
# ('75209', (55, 'priya sriram'))
# ('74118', (98, 'syenix'))
# ('36943', (3515, 'user3319400'))
# ('75276', (170, 'heromonk'))
# ('75336', (273, 'juan gonzález'))
# ('70132', (156, 'arindam'))
# ('75370', (1132, 'arjepak'))
# ('75430', (110, 'pet'))
# ('73938', (1409, 'guilherme felipe reis'))
# ('75502', (254, 'harish reddy'))
# ('75432', (73, 'wouter vandenputte'))
# ('75539', (273, 'anonymous emu'))
# ('47449', (43, 'ranafire'))
# ('75557', (113, 'julian'))
# ('75586', (62, 'user253546'))
# ('75468', (576, 'user2015915'))
# ('75787', (141, 'prashanth'))
# ('70642', (227, 'ruka'))
# ('75642', (69, 'brigitte1trick'))
# ('75973', (133, 'patelnets'))
# ('76001', (100, 'delan'))
# ('76020', (164, 'biel43'))
# ('76085', (374, 'clarity123'))
# ('18298', (139, 'george liu'))
# ('76138', (29, 'tresor koffi'))
# ('76146', (300, 'yassem'))
# ('8738', (83, 'anant gupta'))
# ('76276', (167, 'sam'))
# ('76284', (794, 'sebmal'))
# ('76338', (100, 'sailesh'))
# ('76394', (258, 'aman agrawal'))
# ('76485', (122, 'vuamitom'))
# ('76007', (66, 'naveed'))
# ('74397', (769, "ashwin geet d'sa"))
# ('76640', (553, 'adhithya jd'))
# ('76674', (4009, 'rex5'))
# ('76681', (1282, 'croll'))
# ('76702', (144, 'brad wheeler'))
# ('76777', (104, 'mako'))
# ('76819', (343, 'bunny'))
# ('76880', (257, 'petrh'))
# ('76904', (282, 'metalslugsnk'))
# ('76930', (114, 'mohan raj raja'))
# ('76939', (184, 'tom kealy'))
# ('76965', (69, 'omar virguez'))
# ('76377', (693, 'omid'))
# ('76364', (165, 'charithreddyv'))
# ('77025', (237, 'this_is_david'))
# ('77204', (368, 'rithwik kukunuri'))
# ('77268', (227, 'zhao liang'))
# ('77311', (231, 'p k'))
# ('77476', (175, 'stephanie lin'))
# ('77503', (486, 'bopinko'))
# ('77434', (729, 'damien lancry'))
# ('42792', (838, 'sole g'))
# ('77645', (101, 'user77645'))
# ('77748', (107, 'martykq'))
# ('77631', (144, 'dwight k'))
# ('77812', (293, 'guest_10215'))
# ('77816', (253, 'anshuman'))
# ('77896', (220, 'arif ahmad'))
# ('58635', (216, 'mnis'))
# ('77992', (635, 'nour'))
# ('78007', (343, 'rmdcunha'))
# ('78027', (138, 'sushanth'))
# ('76023', (670, 'jean'))
# ('29889', (754, 'ashutosh'))
# ('78102', (452, 'aggamarcel'))
# ('78159', (2116, 'hassaan'))
# ('71116', (121, 'alexm'))
# ('78232', (382, 'jaime'))
# ('78277', (217, 'hellohelloheloo'))
# ('53961', (246, 'jks612'))
# ('78372', (598, 'raulb1'))
# ('78376', (174, 'sven r. kunze'))
# ('78409', (4167, 'jarsofjam-scheduler'))
# ('78431', (262, 'sarunas'))
# ('77771', (116, 'preetkaran singh'))
# ('78535', (649, 'peter westfall'))
# ('78623', (59, 'pciunkiewicz'))
# ('78758', (802, 'aamir ahmad ansari'))
# ('78867', (1454, 'curious'))
# ('78929', (1109, 'colin c'))
# ('78955', (798, 'skywalkerdk'))
# ('78963', (159, 'rafay kalim'))
# ('78998', (264, 'dkl'))
# ('79058', (219, 'skier'))
# ('79071', (565, 'joenahmias'))
# ('79225', (209, 'lovelyn david'))
# ('79331', (1130, 'hamidreza davirani'))
# ('59028', (10340, 'onur ozbek'))
# ('60482', (291, 'jeremy radcliff'))
# ('79403', (37, 'prince'))
# ('70947', (165, 'salman tabatabai'))
# ('79596', (595, 'zafar'))
# ('79602', (368, 'corianne1234'))
# ('79603', (61, 'salman k'))
# ('79613', (699, 'bobo yang'))
# ('79627', (86, 'caspian sea seal'))
# ('79643', (40, 'kaja. gowtham'))
# ('79655', (3089, 'brentertainer'))
# ('79666', (210, 'waf'))
# ('79735', (273, 'davidm'))
# ('79759', (243, 'nam vu'))
# ('70031', (187, 'eswar'))
# ('80031', (161, 'mathias'))
# ('80072', (700, 'andrea moro'))
# ('80269', (28, 'riku'))
# ('79333', (130, 'shlee'))
# ('80314', (162, 'user666'))
# ('80357', (189, 'habib anwar'))
# ('80375', (258, 'ashish lijhara'))
# ('80415', (170, 'reaz'))
# ('80445', (794, 'aname'))
# ('80447', (124, 'jab'))

# %% [markdown]
# # Question 5
#
# Question Text: "GRADUATE STUDENTS: Using the users.xml, comments.xml and PostHistory.xml files, produce a single file that includes the following information: DisplayName, Number of Comments, total Score and Number of posts. This file should have the users (DisplayName) sorted by score, descending from higher to lower. (40 points)"

# %%
comments = sc.textFile("Comments.xml")


# Key-value pairs of (UserId, comment score)
userScores = comments.map(lambda line: (GetAttributeValue(line, "UserId"), 
                                        int(GetAttributeValue(line, "Score", returnNA=False))))
# This sums the score over each user
totalUserScore = userScores.reduceByKey(lambda x, y: x + y)



# Key-value pairs of (UserId, 1) for each comment in the file
userComments = comments.map(lambda line: (GetAttributeValue(line, "UserId"), 1))
# Since there is a key-value pair of (UserId, 1) for each comment, upon being reduced
# we get (UserId, N), where N is the number of comments
totalUserComments = userComments.reduceByKey(lambda x, y: x + y)



# Filtering to only have titles of posts rather than body text.
titlesOnly = posts.filter(lambda line: GetAttributeValue(line, 'PostHistoryTypeId') == '1')
# Key-value pairs of (UserId, 1) for each post in the file.
userPosts = titlesOnly.map(lambda line: (GetAttributeValue(line, 'UserId'), 1))
totalUserPosts = userPosts.reduceByKey(lambda x, y: x + y)



# Join the various metrics we're concerned with. Also prints to console the number of observations
# that we're losing.
commentsAndScores = totalUserScore.join(totalUserComments)
print("Merging user score and user comments RDDs.\n",
      "Users in the user comments RDD:", totalUserComments.count(),"\n",
      "Users in the user score RDD:", totalUserScore.count(),"\n",
      "Users in the merged file:", commentsAndScores.count(),"\n")

masterNoNames = commentsAndScores.leftOuterJoin(totalUserPosts)
print("Merging user score and comments RDD with user posts RDD.\n",
      "Users in the user comments and score RDD:", commentsAndScores.count(),"\n",
      "Users in the user posts RDD:", totalUserPosts.count(),"\n",
      "Users in the merged file:", masterNoNames.count(),"\n")

master = masterNoNames.join(linkedNames)
print("Merging comments/score/posts RDD with DisplayNames.\n",
      "Users in the comments/score/posts RDD:", masterNoNames.count(),"\n",
      "Users in the DisplayName RDD:", linkedNames.count(),"\n",
      "Users in the merged file:", master.count(),"\n")



# Rearrange the content of each key-value pair to be in the order specified in the problem.
# It looks messy due to the nesting from the merges, but the resulting data is in the following order:

# DisplayName, number of comments, total score, total posts
masterClean = master.map(lambda line: (line[1][1], line[1][0][0][1], line[1][0][0][0], line[1][0][1]))

# Sort by total comment score and save as text file.
masterCleanSorted = masterClean.sortBy(lambda x: x[2], ascending=False)
print("Writing to text file...")
print("Each line has the following format: (DisplayName, Number of Comments, Total Score, Number of Posts)")

with open('MasterSorted.txt', 'w') as file:
    for element in masterCleanSorted.collect():
        for item in element:
            file.write(str(item) + ", ")
        file.write("\n")

print("Finished writing.")
# Out:
# Merging user score and user comments RDDs.
#  Users in the user comments RDD: 8007
#  Users in the user score RDD: 8007
#  Users in the merged file: 8007
#
# Merging user score and comments RDD with user posts RDD.
#  Users in the user comments and score RDD: 8007
#  Users in the user posts RDD: 10532
#  Users in the merged file: 8007
#
# Merging comments/score/posts RDD with DisplayNames.
#  Users in the comments/score/posts RDD: 8007
#  Users in the DisplayName RDD: 66954
#  Users in the merged file: 8008
#
# Writing to text file...
# Each line has the following format: (DisplayName, Number of Comments, Total Score, Number of Posts)
# Finished writing.

# %% [markdown]
# # Note:
#
# In the above section of code, I merge the score and comments RDD with the user posts RDD with a leftOuterJoin. There are many users with posts but no comments. I decide to do this to remove them from the data, as the resulting None for comment count and score seem to go against what you expect for the rest of the problem.
